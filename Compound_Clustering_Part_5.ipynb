# %% [markdown]
# # **Compound clustering**

# %% [markdown]
# ### Contents in _Theory_
#
# * Introduction to clustering and Jarvis-Patrick algorithm
# * Detailed explanation of Butina clustering
# * Picking diverse compounds

# %% [markdown]
# ### References
#
# * Butina, D. Unsupervised Data Base Clustering Based on Daylight’s Fingerprint and Tanimoto Similarity: A Fast and Automated Way To Cluster Small and Large Data Set. _J. Chem. Inf. Comput. Sci._ (1999)
# * Leach, Andrew R., Gillet, Valerie J. An Introduction to Chemoinformatics (2003)
# * [Jarvis-Patrick Clustering](http://www.improvedoutcomes.com/docs/WebSiteDocs/Clustering/Jarvis-Patrick_Clustering_Overview.htm)
# * [TDT Tutorial](https://github.com/sriniker/TDT-tutorial-2014/blob/master/TDT_challenge_tutorial.ipynb)
# * [RDKit clustering documentation](http://rdkit.org/docs/Cookbook.html#clustering-molecules)

# %% [markdown]
# ## Theory

# %% [markdown]
# ### Introduction to clustering and Jarvis-Patrick algorithm
#
# [Clustering](https://en.wikipedia.org/wiki/Cluster_analysis) can be defined as _the task of grouping a set of objects in such a way that objects in the same group (called a cluster) are more similar (in some sense) to each other than to those in other groups (clusters)_.
#
# Compound clustering in pharmaceutical research is often based on chemical or structural similarity between compounds to find groups that share properties as well as to design a diverse and representative set for further analysis.
#
# General procedure:
#
# * Methods are based on clustering data by similarity between neighboring points, as in the case of cheminformatics, compounds are often encoded as molecular fingerprints and similarity.
#
# > Quick reminder:
# >
# >   * Fingerprints are binary vectors where each bit indicates the presence or absence of a particular substructural fragment within a molecule.
# >   * Similarity (or distance) matrix: The similarity between each pair of molecules represented by binary fingerprints is most frequently quantified using the Tanimoto coefficient, which measures the number of common features (bits).
# >   * The value of the Tanimoto coefficient ranges from zero (no similarity) to one (high similarity).
#
# There are a number of clustering algorithms available, with the [Jarvis-Patrick clustering](http://www.improvedoutcomes.com/docs/WebSiteDocs/Clustering/Jarvis-Patrick_Clustering_Overview.htm) being one of the most widely used algorithms in the pharmaceutical context.
#
# Jarvis-Patrick clustering algorithm is defined by two parameters $K$ and $K_{min}$:
#
# * Calculate the set of $K$ nearest neighbors for each molecule.
# * Two molecules cluster together if
#     * they are in each others list of nearest neighbors
#     * they have at least $K_{min}$ of their $K$ nearest neighbors in common.
#
# The Jarvis-Patrick clustering algorithm is deterministic and able to deal with large sets of molecules in a matter of a few hours. However, a downside lies in the fact that this method tends to produce large heterogeneous clusters (see _Butina clustering_, referenced above).
#
# More clustering algorithms can also be found in the [scikit-learn clustering module](http://scikit-learn.org/stable/modules/clustering.html).

# %% [markdown]
# ### Detailed explanation of Butina clustering
#
# Butina clustering ([*J. Chem. Inf. Model.* (1999), **39** (4), 747](https://pubs.acs.org/doi/abs/10.1021/ci9803381)) was developed to identify smaller but homogeneous clusters, with the prerequisite that (at least) the cluster centroid will be more similar than a given threshold to every other molecule in the cluster.
#
# These are the key steps in this clustering approach (see flowchart below):
#
# #### 1. Data preparation and compound encoding
#
# * To identify chemical similarities, the compounds in the input data (e.g. given as SMILES) will be encoded as molecular fingerprints, e.g., RDK5 fingerprint which is a subgraph-based fingerprint similar to the well known [Daylight Fingerprint](http://www.daylight.com/dayhtml/doc/theory/theory.finger.html) (which was used in the original publication).
#
#
# #### 2. Tanimoto similarity (or distance) matrix
#
# * The similarity between two fingerprints is calculated using the Tanimoto coefficient.
# * Matrix with Tanimoto similarities between all possible molecule/fingerprint pairs ($n*n$ similarity matrix with $n$=number of molecules, upper triangle matrix used only).
# * Equally, the distances matrix can be calculated ($1 - similarity$).
#
# #### 3. Clustering molecules: Centroids and exclusion spheres
#
# > Note: Molecules will be clustered together, if they have a maximum distance below a specified cut-off from the cluster centroid (if distance matrix is used) or if they have a minimum similarity above the specified cut-off (if similarity matrix is used).
#
# * **Identification of potential cluster centroids**
#     * The cluster centroid is the molecule within a given cluster which has the largest number of neighbors.
#     * Annotate neighbors: For each molecule count all molecules with a Tanimoto distance below a given threshold.
#     * Sort the molecules by their number of neighbors in descending order, so that potential cluster centroids (i.e. the compounds with the largest number of neighbors) are placed at the top of the file.
#
# * **Clustering based on the exclusion spheres**
#     * Starting with the first molecule (centroid) in the sorted list.
#         * All molecules with a Tanimoto index above or equal to the cut-off value used for clustering then become members of that cluster (in case of similarity).
#             * Each molecule that has been identified as a member of the given cluster is flagged and removed from further comparisons. Thus, flagged molecules cannot become either another cluster centroid or a member of another cluster. This process is like putting an exclusion sphere around the newly formed cluster.
#             * Once the first compound in the list has found all its neighbors, the first available (i.e. not flagged) compound at the top of the list becomes the new cluster centroid.
#         * The same process is repeated for all other unflagged molecules down the list.
#     * Molecules that have not been flagged by the end of the clustering process become singletons.
#         * Note that some molecules assigned as singletons can have neighbors at the given Tanimoto similarity index, but those neighbors have been excluded by a stronger cluster centroid.

# %%
from IPython.display import IFrame

IFrame("images/butina_full.pdf", width=800, height=500)
# Out:
#         <iframe
#             width="800"
#             height="500"
#             src="images/butina_full.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# *Figure 1:* Theoretical example of the Butina clustering algorithm, drawn by Calvinna Caswara.

# %% [markdown]
# ### Picking diverse compounds
#
# Finding representative sets of compounds is a concept often used in pharmaceutical industry.
#
# * Let's say, a virtual screening campaign was applied but only have a limited amount of resources to experimentally test a few compounds in a confirmatory assay.
# * In order to obtain as much information as possible from this screen, want to select a diverse set. Thus, pick one representative of each chemical series in our list of potentially active compounds.
#
# Another scenario would be to select one series to gain information about the structure-activity relationship; i.e., how small structural changes in the molecule affect the _in vitro_ activity.

# %% [markdown]
# ## Lets Start Learning

# %% [markdown]
# #### **Installation of Packages**

# %%
#Install Conda - Kernal Restart will take place
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# Install mamba
# !conda install -c conda-forge mamba -y

# Use mamba to install packages
# !mamba install -c conda-forge -c defaults python=3.8 -y
# !mamba install -c conda-forge -c defaults pip -y
# !mamba install -c conda-forge -c defaults jupyterlab=3 -y
# !mamba install -c conda-forge -c defaults jsonschema=4.3.0 -y
# !mamba install -c conda-forge -c defaults nglview=3 -y
# !mamba install -c conda-forge -c defaults ipywidgets=7.75 -y
# !mamba install -c conda-forge -c defaults jupyter_client=7.4.9 -y
# !mamba install -c conda-forge -c defaults 'numpy<1.24' -y
# !mamba install -c conda-forge -c defaults scikit-learn -y
# !mamba install -c conda-forge -c defaults 'tensorflow<=2.6' -y
# !mamba install -c conda-forge -c defaults seaborn -y
# !mamba install -c conda-forge -c defaults matplotlib-venn -y
# !mamba install -c conda-forge -c defaults bravado -y
# !mamba install -c conda-forge -c defaults requests -y
# !mamba install -c conda-forge -c defaults requests-cache -y
# !mamba install -c conda-forge -c defaults redo -y
# !mamba install -c conda-forge -c defaults suds-community -y
# !mamba install -c conda-forge -c defaults beautifulsoup4 -y
# !mamba install -c conda-forge -c defaults chembl_webresource_client -y
# !mamba install -c conda-forge -c defaults pypdb -y
# !mamba install -c conda-forge -c defaults 'biopython<=1.77' -y
# !mamba install -c conda-forge -c defaults biopandas -y
# !mamba install -c conda-forge -c defaults rdkit -y
# !mamba install -c conda-forge -c defaults openbabel -y
# !mamba install -c conda-forge -c defaults opencadd -y
# !mamba install -c conda-forge -c defaults 'biotite>=0.34.0' -y
# !mamba install -c conda-forge -c defaults smina -y
# !mamba install -c conda-forge -c defaults 'mdanalysis>=1.0.0' -y
# !mamba install -c conda-forge -c defaults mdtraj -y
# !mamba install -c conda-forge -c defaults plip -y
# !mamba install -c conda-forge -c defaults openmm -y
# !mamba install -c conda-forge -c defaults 'mkl<2022' -y
# !mamba install -c pytorch pytorch==1.13.0 -y
# !mamba install -c conda-forge -c defaults pdbfixer -y
# !mamba install -c conda-forge -c defaults tqdm -y
# !mamba install -c conda-forge -c defaults lxml -y
# !mamba install -c conda-forge -c defaults kissim -y
# !mamba install -c conda-forge -c defaults pytest -y
# !mamba install -c conda-forge -c defaults pytest-xdist -y
# !mamba install -c conda-forge -c defaults pytest-cov -y
# !mamba install -c conda-forge -c defaults nbval -y
# !mamba install -c conda-forge -c defaults shyaml -y
# !mamba install -c conda-forge -c defaults 'jinja2==3.0.3' -y
# !mamba install -c conda-forge -c defaults sphinx -y
# !mamba install -c conda-forge -c defaults sphinx-material -y
# !mamba install -c conda-forge -c defaults nbsphinx -y
# !mamba install -c conda-forge -c defaults recommonmark -y
# !mamba install -c conda-forge -c defaults sphinx-autodoc-typehints -y
# !mamba install -c conda-forge -c defaults sphinx-copybutton -y
# !mamba install -c conda-forge -c defaults sphinx-gallery -y
# !mamba install -c conda-forge -c defaults autodocsumm -y

# Install pip packages
# !pip install black-nb nbsphinx-link sphinxext-opengraph deepchem
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# | ^C
# Traceback (most recent call last):
#   File "/usr/local/bin/mamba", line 7, in <module>
#     from mamba.mamba import main
#   File "/usr/local/lib/python3.10/site-packages/mamba/mamba.py", line 14, in <module>
#     from conda.base.constants import ChannelPriority, DepsModifier, UpdateModifier
#   File "/usr/local/lib/python3.10/site-packages/conda/base/constants.py", line 15, in <module>
#     from ..common.compat import on_win, six_with_metaclass
#   File "/usr/local/lib/python3.10/site-packages/conda/common/compat.py", line 13, in <module>
#     from ..deprecations import deprecated
#   File "/usr/local/lib/python3.10/site-packages/conda/deprecations.py", line 12, in <module>
#     from typing import TYPE_CHECKING
#   File "/usr/local/lib/python3.10/typing.py", line 2664, in <module>
#     Pattern = _alias(stdlib_re.Pattern, 1)
#   File "/usr/local/lib/python3.10/typing.py", line 1128, in __init__
#     def __init__(self, origin, nparams, *, inst=True, name=None):
# KeyboardInterrupt
# ^C
#
# Looking for: ['pip']
#
# warning  libmamba Cache file "/usr/local/pkgs/cache/497deca9.json" was modified by another program
# warning  libmamba Cache file "/usr/local/pkgs/cache/09cdf8bf.json" was modified by another program
# warning  libmamba Cache file "/usr/local/pkgs/cache/47929eba.json" was modified by another program
# [+] 0.0s
# pkgs/main/linux-64..  ⣾  pkgs/main/linux-64 (check zst)
# warning  libmamba Cache file "/usr/local/pkgs/cache/3e39a7aa.json" was modified by another program
# [+] 0.0s
# pkgs/main/noarch (check zst)                       Checked  0.0s
# [+] 0.0s
# pkgs/r/linux-64                                               No change
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾
# pkgs/r/noarch        100%
# pkgs/main/linux-64     1%
# pkgs/main/noarch      ⣾  pkgs/r/noarch
# [+] 0.2s
# conda-forge/linux-64   1%
# conda-forge/noarch     1%
# pkgs/main/linux-64    16%
# pkgs/main/noarch      90%pkgs/main/noarch
# [+] 0.3s
# conda-forge/linux-64   1%
# conda-forge/noarch     1%
# pkgs/main/linux-64    21%[+] 0.4s
# conda-forge/linux-64   3%
# conda-forge/noarch     4%
# pkgs/main/linux-64    39%[+] 0.5s
# conda-forge/linux-64   5%
# conda-forge/noarch     5%
# pkgs/main/linux-64    57%[+] 0.6s
# conda-forge/linux-64   6%
# conda-forge/noarch     8%
# pkgs/main/linux-64    65%[+] 0.7s
# conda-forge/linux-64   8%
# conda-forge/noarch    11%
# pkgs/main/linux-64    76%[+] 0.8s
# conda-forge/linux-64   9%
# conda-forge/noarch    13%
# pkgs/main/linux-64    89%[+] 0.9s
# conda-forge/linux-64  10%
# conda-forge/noarch    15%
# pkgs/main/linux-64    91%[+] 1.0s
# conda-forge/linux-64  11%
# conda-forge/noarch    17%
# pkgs/main/linux-64    94%pkgs/main/linux-64
# [+] 1.1s
# conda-forge/linux-64  13%
# conda-forge/noarch    20%[+] 1.2s
# conda-forge/linux-64  14%
# conda-forge/noarch    24%[+] 1.3s
# conda-forge/linux-64  18%
# conda-forge/noarch    29%[+] 1.4s
# conda-forge/linux-64  20%
# conda-forge/noarch    35%[+] 1.5s
# conda-forge/linux-64  23%
# conda-forge/noarch    39%[+] 1.6s
# conda-forge/linux-64  27%
# conda-forge/noarch    47%[+] 1.7s
# conda-forge/linux-64  29%
# conda-forge/noarch    56%[+] 1.8s
# conda-forge/linux-64  34%
# conda-forge/noarch    66%[+] 1.9s
# conda-forge/linux-64  38%
# conda-forge/noarch    76%[+] 2.0s
# conda-forge/linux-64  40%
# conda-forge/noarch    80%[+] 2.1s
# conda-forge/linux-64  42%
# conda-forge/noarch    85%[+] 2.2s
# conda-forge/linux-64  43%
# conda-forge/noarch    87%[+] 2.3s
# conda-forge/linux-64  44%
# conda-forge/noarch    92%[+] 2.4s
# conda-forge/linux-64  47%
# conda-forge/noarch    97%conda-forge/noarch
# [+] 2.5s
# conda-forge/linux-64  48%[+] 2.6s
# conda-forge/linux-64  52%[+] 2.7s
# conda-forge/linux-64  59%[+] 2.8s
# conda-forge/linux-64  65%[+] 2.9s
# conda-forge/linux-64  71%[+] 3.0s
# conda-forge/linux-64  73%[+] 3.1s
# conda-forge/linux-64  73%[+] 3.2s
# conda-forge/linux-64  74%[+] 3.3s
# conda-forge/linux-64  74%[+] 3.4s
# conda-forge/linux-64  74%[+] 3.5s
# conda-forge/linux-64  74%[+] 3.6s
# conda-forge/linux-64  74%[+] 3.7s
# conda-forge/linux-64  74%[+] 3.8s
# conda-forge/linux-64  74%[+] 3.9s
# conda-forge/linux-64  74%[+] 4.0s
# conda-forge/linux-64  75%[+] 4.1s
# conda-forge/linux-64  75%[+] 4.2s
# conda-forge/linux-64  75%[+] 4.3s
# conda-forge/linux-64  75%[+] 4.4s
# conda-forge/linux-64  75%[+] 4.5s
# conda-forge/linux-64  75%[+] 4.6s
# conda-forge/linux-64  75%[+] 4.7s
# conda-forge/linux-64  75%[+] 4.8s
# conda-forge/linux-64  75%[+] 4.9s
# conda-forge/linux-64  75%[+] 5.0s
# conda-forge/linux-64  75%[+] 5.1s
# conda-forge/linux-64  75%[+] 5.2s
# conda-forge/linux-64  75%[+] 5.3s
# conda-forge/linux-64  75%[+] 5.4s
# conda-forge/linux-64  75%[+] 5.5s
# conda-forge/linux-64  75%[+] 5.6s
# conda-forge/linux-64  75%[+] 5.7s
# conda-forge/linux-64  83%[+] 5.8s
# conda-forge/linux-64  92%[+] 5.9s
# conda-forge/linux-64 100%[+] 6.0s
# conda-forge/linux-64 100%[+] 6.1s
# conda-forge/linux-64 100%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['jupyterlab=3']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch       ⣾  pkgs/r/linux-64                                               No change
# [+] 0.1s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/noarch       ⣾  pkgs/main/noarch                                              No change
# pkgs/main/linux-64                                            No change
# pkgs/r/noarch                                                 No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - jupyterlab=3
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package       Version  Build         Channel           Size
# ───────────────────────────────────────────────────────────────
#   Downgrade:
# ───────────────────────────────────────────────────────────────
#
#   - notebook      7.3.2  pyhd8ed1ab_0  conda-forge     Cached
#   + notebook      6.5.7  pyha770c72_0  conda-forge     Cached
#   - nglview       3.1.4  pyh620948e_0  conda-forge     Cached
#   + nglview       3.0.8  pyh1da8cd4_0  conda-forge        7MB
#   - jupyterlab    4.3.4  pyhd8ed1ab_0  conda-forge     Cached
#   + jupyterlab    3.6.8  pyhd8ed1ab_0  conda-forge     Cached
#
#   Summary:
#
#   Downgrade: 3 packages
#
#   Total download: 7MB
#
# ───────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading  (1)   0%
# Extracting         0%[+] 0.1s
# Downloading  (1)   1%
# Extracting         0%nglview                                              6.7MB @  34.4MB/s  0.2s
# [+] 0.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 0.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 0.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 0.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 0.6s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['jsonschema=4.3.0']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch       ⣾  pkgs/main/linux-64                                            No change
# pkgs/r/noarch                                                 No change
# pkgs/r/linux-64                                               No change
# [+] 0.1s
# pkgs/main/noarch  ⣾  pkgs/main/noarch                                              No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - jsonschema=4.3.0
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                          Version  Build         Channel           Size
# ──────────────────────────────────────────────────────────────────────────────────
#   Downgrade:
# ──────────────────────────────────────────────────────────────────────────────────
#
#   - jsonschema                      4.23.0  pyhd8ed1ab_1  conda-forge     Cached
#   + jsonschema                       4.3.0  pyhd8ed1ab_0  conda-forge     Cached
#   - jupyterlab_server               2.27.3  pyhd8ed1ab_1  conda-forge     Cached
#   + jupyterlab_server               2.16.6  pyhd8ed1ab_0  conda-forge     Cached
#   - jsonschema-with-format-nongpl   4.23.0  hd8ed1ab_1    conda-forge     Cached
#   + jsonschema-with-format-nongpl    4.3.0  pyhd8ed1ab_0  conda-forge     Cached
#   - jupyterlab                       3.6.8  pyhd8ed1ab_0  conda-forge     Cached
#   + jupyterlab                       3.5.3  pyhd8ed1ab_0  conda-forge     Cached
#
#   Summary:
#
#   Downgrade: 4 packages
#
#   Total download: 0 B
#
# ──────────────────────────────────────────────────────────────────────────────────
#
#
#
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['nglview=3']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch       ⣾  pkgs/main/linux-64                                            No change
# pkgs/main/noarch                                              No change
# [+] 0.1s
# pkgs/r/linux-64  ⣾
# pkgs/r/noarch    ⣾  pkgs/r/linux-64                                               No change
# pkgs/r/noarch                                                 No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['ipywidgets=7.75']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch       ⣾  pkgs/main/noarch                                              No change
# pkgs/r/linux-64                                               No change
# pkgs/main/linux-64                                            No change
# pkgs/r/noarch                                                 No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Could not solve for environment specs
# The following package could not be installed
# └─ ipywidgets 7.75**  does not exist (perhaps a typo or a missing channel).
#
# Looking for: ['jupyter_client=7.4.9']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ["numpy[version='<1.24']"]
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch       ⣾  pkgs/main/noarch                                              No change
# pkgs/r/linux-64                                               No change
# [+] 0.1s
# pkgs/main/linux-64  ⣾
# pkgs/r/noarch       ⣾  pkgs/r/noarch                                                 No change
# pkgs/main/linux-64                                            No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# Could not solve for environment specs
# The following packages are incompatible
# ├─ biotite is installable with the potential options
# │  ├─ biotite [1.0.1|1.1.0] would require
# │  │  └─ numpy >=1.26  with the potential options
# │  │     ├─ numpy 1.26.4, which can be installed;
# │  │     ├─ numpy [1.22.3|1.23.4|...|2.2.1] would require
# │  │     │  └─ python >=3.11,<3.12.0a0 , which can be installed;
# │  │     ├─ numpy [1.16.6|1.19.2|...|2.0.2] would require
# │  │     │  └─ python >=3.9,<3.10.0a0 , which can be installed;
# │  │     ├─ numpy [1.26.0|1.26.2|1.26.3], which can be installed;
# │  │     ├─ numpy 1.26.0 would require
# │  │     │  └─ python >=3.12.0rc3,<3.13.0a0  with the potential options
# │  │     │     ├─ python [3.12.0|3.12.1|...|3.12.8], which can be installed;
# │  │     │     └─ python [3.12.0rc3|3.13.0rc1|3.13.0rc2|3.13.0rc3] would require
# │  │     │        └─ _python_rc, which does not exist (perhaps a missing channel);
# │  │     ├─ numpy [1.26.0|1.26.2|...|2.2.1] would require
# │  │     │  └─ python >=3.12,<3.13.0a0 , which can be installed;
# │  │     ├─ numpy [2.0.0|2.0.1|...|2.2.1], which can be installed;
# │  │     ├─ numpy [2.0.0rc1|2.0.0rc2|2.1.0rc1|2.2.0rc1] would require
# │  │     │  └─ _numpy_rc, which does not exist (perhaps a missing channel);
# │  │     ├─ numpy [2.1.0|2.1.1|2.1.2] would require
# │  │     │  └─ python [>=3.13.0rc1,<3.14.0a0 |>=3.13.0rc3,<3.14.0a0 ] with the potential options
# │  │     │     ├─ python [3.12.0rc3|3.13.0rc1|3.13.0rc2|3.13.0rc3], which cannot be installed (as previously explained);
# │  │     │     └─ python [3.13.0|3.13.1], which can be installed;
# │  │     └─ numpy [2.1.2|2.1.3|2.2.0|2.2.1] would require
# │  │        └─ python >=3.13,<3.14.0a0 , which can be installed;
# │  ├─ biotite [0.12.0|0.13.0|...|0.25.0] would require
# │  │  └─ python >=3.6,<3.7.0a0 , which can be installed;
# │  ├─ biotite [0.12.0|0.13.0|...|0.31.0] would require
# │  │  └─ python >=3.7,<3.8.0a0 , which can be installed;
# │  ├─ biotite [0.17.0|0.18.0|...|0.35.0] would require
# │  │  └─ python >=3.8,<3.9.0a0 , which can be installed;
# │  ├─ biotite [0.25.0|0.26.0|...|0.38.0] would require
# │  │  └─ python >=3.9,<3.10.0a0 , which can be installed;
# │  ├─ biotite [0.31.0|0.32.0] would require
# │  │  └─ numpy >=1.21.5,<2.0a0  with the potential options
# │  │     ├─ numpy 1.26.4, which can be installed;
# │  │     ├─ numpy [1.25.0|1.25.1|1.25.2], which can be installed;
# │  │     ├─ numpy [1.22.3|1.23.4|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.16.6|1.19.2|...|2.0.2], which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|1.26.3], which can be installed;
# │  │     ├─ numpy 1.26.0, which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.22.4|1.23.0|...|1.23.5] conflicts with any installable versions previously reported;
# │  │     ├─ numpy [1.11.3|1.13.3|...|1.24.4] would require
# │  │     │  └─ python >=3.8,<3.9.0a0 , which can be installed;
# │  │     ├─ numpy [1.24.0|1.24.1|1.24.2|1.24.3|1.24.4], which can be installed;
# │  │     ├─ numpy 1.23.3 would require
# │  │     │  └─ numpy-base 1.23.3 py310h375b286_0, which does not exist (perhaps a missing channel);
# │  │     ├─ numpy 1.23.3 would require
# │  │     │  └─ numpy-base 1.23.3 py310h8e6c178_0, which does not exist (perhaps a missing channel);
# │  │     ├─ numpy [1.21.6|1.22.0|1.22.1|1.22.2] conflicts with any installable versions previously reported;
# │  │     ├─ numpy [1.11.3|1.14.5|...|1.9.3] would require
# │  │     │  └─ python >=3.7,<3.8.0a0 , which can be installed;
# │  │     ├─ numpy 1.22.3 conflicts with any installable versions previously reported;
# │  │     └─ numpy 1.21.5 conflicts with any installable versions previously reported;
# │  ├─ biotite [0.33.0|0.34.0|...|0.37.0] would require
# │  │  └─ numpy >=1.21.6,<2.0a0  with the potential options
# │  │     ├─ numpy 1.26.4, which can be installed;
# │  │     ├─ numpy [1.25.0|1.25.1|1.25.2], which can be installed;
# │  │     ├─ numpy [1.22.3|1.23.4|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.16.6|1.19.2|...|2.0.2], which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|1.26.3], which can be installed;
# │  │     ├─ numpy 1.26.0, which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.22.4|1.23.0|...|1.23.5] conflicts with any installable versions previously reported;
# │  │     ├─ numpy [1.11.3|1.13.3|...|1.24.4], which can be installed (as previously explained);
# │  │     ├─ numpy [1.24.0|1.24.1|1.24.2|1.24.3|1.24.4], which can be installed;
# │  │     ├─ numpy 1.23.3, which cannot be installed (as previously explained);
# │  │     ├─ numpy 1.23.3, which cannot be installed (as previously explained);
# │  │     ├─ numpy [1.21.6|1.22.0|1.22.1|1.22.2] conflicts with any installable versions previously reported;
# │  │     ├─ numpy [1.11.3|1.14.5|...|1.9.3], which can be installed (as previously explained);
# │  │     └─ numpy 1.22.3 conflicts with any installable versions previously reported;
# │  ├─ biotite [0.35.0|0.36.0|...|1.1.0] would require
# │  │  └─ python >=3.11,<3.12.0a0 , which can be installed;
# │  ├─ biotite [0.38.0|0.39.0] would require
# │  │  └─ numpy >=1.22.4,<2.0a0  with the potential options
# │  │     ├─ numpy 1.26.4, which can be installed;
# │  │     ├─ numpy [1.25.0|1.25.1|1.25.2], which can be installed;
# │  │     ├─ numpy [1.22.3|1.23.4|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.16.6|1.19.2|...|2.0.2], which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|1.26.3], which can be installed;
# │  │     ├─ numpy 1.26.0, which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.22.4|1.23.0|...|1.23.5] conflicts with any installable versions previously reported;
# │  │     ├─ numpy [1.11.3|1.13.3|...|1.24.4], which can be installed (as previously explained);
# │  │     ├─ numpy [1.24.0|1.24.1|1.24.2|1.24.3|1.24.4], which can be installed;
# │  │     ├─ numpy 1.23.3, which cannot be installed (as previously explained);
# │  │     └─ numpy 1.23.3, which cannot be installed (as previously explained);
# │  ├─ biotite [0.38.0|0.39.0|...|1.1.0] would require
# │  │  └─ python >=3.12,<3.13.0a0 , which can be installed;
# │  ├─ biotite 0.38.0 would require
# │  │  └─ python >=3.12.0rc3,<3.13.0a0  with the potential options
# │  │     ├─ python [3.12.0|3.12.1|...|3.12.8], which can be installed;
# │  │     └─ python [3.12.0rc3|3.13.0rc1|3.13.0rc2|3.13.0rc3], which cannot be installed (as previously explained);
# │  ├─ biotite [0.40.0|0.41.0] would require
# │  │  └─ numpy >=1.26.4,<2.0a0  with the potential options
# │  │     ├─ numpy 1.26.4, which can be installed;
# │  │     ├─ numpy [1.22.3|1.23.4|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.16.6|1.19.2|...|2.0.2], which can be installed (as previously explained);
# │  │     └─ numpy [1.26.0|1.26.2|...|2.2.1], which can be installed (as previously explained);
# │  └─ biotite 1.1.0 would require
# │     └─ python >=3.13,<3.14.0a0 , which can be installed;
# ├─ biotraj is installable with the potential options
# │  ├─ biotraj [1.2.0|1.2.1|1.2.2] would require
# │  │  └─ numpy >=1.26  with the potential options
# │  │     ├─ numpy 1.26.4, which can be installed;
# │  │     ├─ numpy [1.22.3|1.23.4|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.16.6|1.19.2|...|2.0.2], which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|1.26.3], which can be installed;
# │  │     ├─ numpy 1.26.0, which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [2.0.0|2.0.1|...|2.2.1], which can be installed;
# │  │     ├─ numpy [2.0.0rc1|2.0.0rc2|2.1.0rc1|2.2.0rc1], which cannot be installed (as previously explained);
# │  │     ├─ numpy [2.1.0|2.1.1|2.1.2], which can be installed (as previously explained);
# │  │     └─ numpy [2.1.2|2.1.3|2.2.0|2.2.1], which can be installed (as previously explained);
# │  ├─ biotraj [1.2.0|1.2.1|1.2.2] would require
# │  │  └─ python >=3.11,<3.12.0a0 , which can be installed;
# │  ├─ biotraj [1.2.0|1.2.1|1.2.2] would require
# │  │  └─ python >=3.12,<3.13.0a0 , which can be installed;
# │  ├─ biotraj 1.2.1 would require
# │  │  └─ python >=3.13.0rc1,<3.14.0a0  with the potential options
# │  │     ├─ python [3.12.0rc3|3.13.0rc1|3.13.0rc2|3.13.0rc3], which cannot be installed (as previously explained);
# │  │     └─ python [3.13.0|3.13.1], which can be installed;
# │  └─ biotraj 1.2.2 would require
# │     └─ python >=3.13,<3.14.0a0 , which can be installed;
# ├─ mdtraj is installable with the potential options
# │  ├─ mdtraj 1.10.2 would require
# │  │  └─ numpy >=1.25.0  with the potential options
# │  │     ├─ numpy 1.26.4, which can be installed;
# │  │     ├─ numpy [1.25.0|1.25.1|1.25.2], which can be installed;
# │  │     ├─ numpy [1.22.3|1.23.4|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.16.6|1.19.2|...|2.0.2], which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|1.26.3], which can be installed;
# │  │     ├─ numpy 1.26.0, which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [2.0.0|2.0.1|...|2.2.1], which can be installed;
# │  │     ├─ numpy [2.0.0rc1|2.0.0rc2|2.1.0rc1|2.2.0rc1], which cannot be installed (as previously explained);
# │  │     ├─ numpy [2.1.0|2.1.1|2.1.2], which can be installed (as previously explained);
# │  │     └─ numpy [2.1.2|2.1.3|2.2.0|2.2.1], which can be installed (as previously explained);
# │  ├─ mdtraj [1.7.2|1.8.0|1.9.1|1.9.2|1.9.3] would require
# │  │  └─ python [2.7* |>=2.7,<2.8.0a0 ], which can be installed;
# │  ├─ mdtraj [1.7.2|1.8.0] would require
# │  │  └─ python 3.4* , which can be installed;
# │  ├─ mdtraj [1.7.2|1.8.0|1.9.1|1.9.2] would require
# │  │  └─ python [3.5* |>=3.5,<3.6.0a0 ], which can be installed;
# │  ├─ mdtraj [1.8.0|1.9.1] would require
# │  │  └─ python 3.6* , which can be installed;
# │  ├─ mdtraj [1.9.1|1.9.2|...|1.9.6] would require
# │  │  └─ python >=3.6,<3.7.0a0 , which can be installed;
# │  ├─ mdtraj [1.9.2|1.9.3|...|1.9.7] would require
# │  │  └─ python >=3.7,<3.8.0a0 , which can be installed;
# │  ├─ mdtraj [1.10.0|1.9.3|...|1.9.9] would require
# │  │  └─ python >=3.8,<3.9.0a0 , which can be installed;
# │  ├─ mdtraj [1.10.0|1.10.1|...|1.9.9] would require
# │  │  └─ python >=3.9,<3.10.0a0 , which can be installed;
# │  ├─ mdtraj [1.9.7|1.9.8|1.9.9] would require
# │  │  └─ numpy >=1.21.6,<2.0a0  with the potential options
# │  │     ├─ numpy 1.26.4, which can be installed;
# │  │     ├─ numpy [1.25.0|1.25.1|1.25.2], which can be installed;
# │  │     ├─ numpy [1.22.3|1.23.4|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.16.6|1.19.2|...|2.0.2], which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|1.26.3], which can be installed;
# │  │     ├─ numpy 1.26.0, which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.22.4|1.23.0|...|1.23.5] conflicts with any installable versions previously reported;
# │  │     ├─ numpy [1.11.3|1.13.3|...|1.24.4], which can be installed (as previously explained);
# │  │     ├─ numpy [1.24.0|1.24.1|1.24.2|1.24.3|1.24.4], which can be installed;
# │  │     ├─ numpy 1.23.3, which cannot be installed (as previously explained);
# │  │     ├─ numpy 1.23.3, which cannot be installed (as previously explained);
# │  │     ├─ numpy [1.21.6|1.22.0|1.22.1|1.22.2] conflicts with any installable versions previously reported;
# │  │     ├─ numpy [1.11.3|1.14.5|...|1.9.3], which can be installed (as previously explained);
# │  │     └─ numpy 1.22.3 conflicts with any installable versions previously reported;
# │  ├─ mdtraj 1.9.7 would require
# │  │  └─ numpy >=1.21.4,<2.0a0  with the potential options
# │  │     ├─ numpy 1.26.4, which can be installed;
# │  │     ├─ numpy [1.25.0|1.25.1|1.25.2], which can be installed;
# │  │     ├─ numpy [1.22.3|1.23.4|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.16.6|1.19.2|...|2.0.2], which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|1.26.3], which can be installed;
# │  │     ├─ numpy 1.26.0, which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.22.4|1.23.0|...|1.23.5] conflicts with any installable versions previously reported;
# │  │     ├─ numpy [1.11.3|1.13.3|...|1.24.4], which can be installed (as previously explained);
# │  │     ├─ numpy [1.24.0|1.24.1|1.24.2|1.24.3|1.24.4], which can be installed;
# │  │     ├─ numpy 1.23.3, which cannot be installed (as previously explained);
# │  │     ├─ numpy 1.23.3, which cannot be installed (as previously explained);
# │  │     ├─ numpy [1.21.6|1.22.0|1.22.1|1.22.2] conflicts with any installable versions previously reported;
# │  │     ├─ numpy [1.11.3|1.14.5|...|1.9.3], which can be installed (as previously explained);
# │  │     ├─ numpy 1.22.3 conflicts with any installable versions previously reported;
# │  │     ├─ numpy 1.21.4 conflicts with any installable versions previously reported;
# │  │     └─ numpy 1.21.5 conflicts with any installable versions previously reported;
# │  ├─ mdtraj [1.10.0|1.10.1|...|1.9.9] would require
# │  │  └─ python >=3.11,<3.12.0a0 , which can be installed;
# │  ├─ mdtraj [1.10.0|1.10.1|1.9.9] would require
# │  │  └─ numpy >=1.22.4,<2.0a0  with the potential options
# │  │     ├─ numpy 1.26.4, which can be installed;
# │  │     ├─ numpy [1.25.0|1.25.1|1.25.2], which can be installed;
# │  │     ├─ numpy [1.22.3|1.23.4|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.16.6|1.19.2|...|2.0.2], which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|1.26.3], which can be installed;
# │  │     ├─ numpy 1.26.0, which can be installed (as previously explained);
# │  │     ├─ numpy [1.26.0|1.26.2|...|2.2.1], which can be installed (as previously explained);
# │  │     ├─ numpy [1.22.4|1.23.0|...|1.23.5] conflicts with any installable versions previously reported;
# │  │     ├─ numpy [1.11.3|1.13.3|...|1.24.4], which can be installed (as previously explained);
# │  │     ├─ numpy [1.24.0|1.24.1|1.24.2|1.24.3|1.24.4], which can be installed;
# │  │     ├─ numpy 1.23.3, which cannot be installed (as previously explained);
# │  │     └─ numpy 1.23.3, which cannot be installed (as previously explained);
# │  ├─ mdtraj [1.10.0|1.10.1|1.10.2|1.9.9] would require
# │  │  └─ python >=3.12,<3.13.0a0 , which can be installed;
# │  └─ mdtraj [1.10.1|1.10.2] would require
# │     └─ python >=3.13,<3.14.0a0 , which can be installed;
# ├─ numpy <1.24  is installable with the potential options
# │  ├─ numpy [1.22.3|1.23.4|...|2.2.1], which can be installed (as previously explained);
# │  ├─ numpy [1.16.6|1.19.2|...|2.0.2], which can be installed (as previously explained);
# │  ├─ numpy [1.22.4|1.23.0|...|1.23.5] conflicts with any installable versions previously reported;
# │  ├─ numpy [1.11.3|1.13.3|...|1.24.4], which can be installed (as previously explained);
# │  ├─ numpy 1.23.3, which cannot be installed (as previously explained);
# │  ├─ numpy 1.23.3, which cannot be installed (as previously explained);
# │  ├─ numpy [1.21.6|1.22.0|1.22.1|1.22.2] conflicts with any installable versions previously reported;
# │  ├─ numpy [1.11.3|1.14.5|...|1.9.3], which can be installed (as previously explained);
# │  ├─ numpy 1.22.3 conflicts with any installable versions previously reported;
# │  ├─ numpy 1.21.4 conflicts with any installable versions previously reported;
# │  ├─ numpy 1.21.5 conflicts with any installable versions previously reported;
# │  ├─ numpy [1.21.2|1.21.3] conflicts with any installable versions previously reported;
# │  ├─ numpy [1.10.4|1.11.0|...|1.9.3] would require
# │  │  └─ python [2.7* |>=2.7,<2.8.0a0 ], which can be installed;
# │  ├─ numpy [1.10.4|1.11.0|...|1.9.3] would require
# │  │  └─ python 3.4* , which can be installed;
# │  ├─ numpy [1.10.4|1.11.0|...|1.9.3] would require
# │  │  └─ python [3.5* |>=3.5,<3.6.0a0 ], which can be installed;
# │  ├─ numpy [1.10.4|1.11.3|...|1.9.3] would require
# │  │  └─ python 3.6* , which can be installed;
# │  └─ numpy [1.11.3|1.12.1|...|1.9.3] would require
# │     └─ python >=3.6,<3.7.0a0 , which can be installed;
# └─ waterdynamics is installable and it requires
#    └─ numpy >=1.22.3  with the potential options
#       ├─ numpy 1.26.4, which can be installed;
#       ├─ numpy [1.25.0|1.25.1|1.25.2], which can be installed;
#       ├─ numpy [1.22.3|1.23.4|...|2.2.1], which can be installed (as previously explained);
#       ├─ numpy [1.16.6|1.19.2|...|2.0.2], which can be installed (as previously explained);
#       ├─ numpy [1.26.0|1.26.2|1.26.3], which can be installed;
#       ├─ numpy 1.26.0, which can be installed (as previously explained);
#       ├─ numpy [1.26.0|1.26.2|...|2.2.1], which can be installed (as previously explained);
#       ├─ numpy [2.0.0|2.0.1|...|2.2.1], which can be installed;
#       ├─ numpy [2.0.0rc1|2.0.0rc2|2.1.0rc1|2.2.0rc1], which cannot be installed (as previously explained);
#       ├─ numpy [2.1.0|2.1.1|2.1.2], which can be installed (as previously explained);
#       ├─ numpy [2.1.2|2.1.3|2.2.0|2.2.1], which can be installed (as previously explained);
#       ├─ numpy [1.22.4|1.23.0|...|1.23.5] conflicts with any installable versions previously reported;
#       ├─ numpy [1.11.3|1.13.3|...|1.24.4], which can be installed (as previously explained);
#       ├─ numpy [1.24.0|1.24.1|1.24.2|1.24.3|1.24.4], which can be installed;
#       ├─ numpy 1.23.3, which cannot be installed (as previously explained);
#       ├─ numpy 1.23.3, which cannot be installed (as previously explained);
#       └─ numpy 1.22.3 conflicts with any installable versions previously reported.
#
# Looking for: ['scikit-learn']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ["tensorflow[version='<=2.6']"]
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch       ⣾  pkgs/main/linux-64                                            No change
# pkgs/main/noarch                                              No change
# [+] 0.1s
# pkgs/r/noarch  ⣾  pkgs/r/linux-64                                               No change
# pkgs/r/noarch                                                 No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# Could not solve for environment specs
# The following packages are incompatible
# └─ tensorflow <=2.6  is installable with the potential options
#    ├─ tensorflow [0.10.0|0.11.0|...|2.1.0] would require
#    │  ├─ python [2.7* |2.7.* |>=2.7,<2.8.0a0 ], which can be installed;
#    │  └─ tensorflow-base [1.13.1 py27h76b4ce7_8|1.13.2 py27h76b4ce7_0|==1.8.0 py27h5f64886_0|==1.8.0 py27hc1a7637_0|==1.8.0 py27hee38f2d_0], which requires
#    │     └─ python >=2.7,<2.8.0a0 , which can be installed;
#    ├─ tensorflow [0.10.0|0.11.0|...|0.9.0] would require
#    │  └─ python 3.4* , which can be installed;
#    ├─ tensorflow [0.10.0|0.11.0|...|1.9.0] would require
#    │  ├─ python [3.5* |3.5.* |>=3.5,<3.6.0a0 ], which can be installed;
#    │  └─ tensorflow-base [==1.8.0 py35h5f64886_0|==1.8.0 py35hc1a7637_0|==1.8.0 py35hee38f2d_0], which requires
#    │     └─ python >=3.5,<3.6.0a0 , which can be installed;
#    ├─ tensorflow [0.12.1|1.0.0|...|2.2.0] would require
#    │  └─ python [3.6* |3.6.* ], which can be installed;
#    ├─ tensorflow [1.10.0|1.13.1|...|2.6.0] would require
#    │  ├─ python >=3.6,<3.7.0a0 , which can be installed;
#    │  └─ tensorflow-base [1.13.1 py36h58012e3_6|1.13.1 py36h76b4ce7_7|==1.8.0 py36h5f64886_0|==1.8.0 py36hc1a7637_0|==1.8.0 py36hee38f2d_0], which requires
#    │     └─ python >=3.6,<3.7.0a0 , which can be installed;
#    ├─ tensorflow [1.13.1|1.14.0|...|2.6.0] would require
#    │  ├─ python [3.7.* |>=3.7,<3.8.0a0 ], which can be installed;
#    │  └─ tensorflow-base [1.13.1 py37h5ece82f_4|1.13.1 py37h5ece82f_5], which requires
#    │     └─ python >=3.7,<3.8.0a0 , which can be installed;
#    ├─ tensorflow 1.14.0 would require
#    │  └─ python_abi 3.7.* *_cp37m, which can be installed;
#    ├─ tensorflow 1.14.0 would require
#    │  └─ python_abi 3.6.* *_cp36m, which can be installed;
#    ├─ tensorflow [2.2.0|2.3.0|...|2.6.0] would require
#    │  └─ python [3.8.* |>=3.8,<3.9.0a0 ], which can be installed;
#    ├─ tensorflow [2.4.1|2.4.3|2.5.0|2.6.0] would require
#    │  └─ python [3.9.* |>=3.9,<3.10.0a0 ], which can be installed;
#    ├─ tensorflow [1.10.0|1.8.0|1.9.0] would require
#    │  └─ tensorflow-base [==1.10.0 gpu_py27h3435052_0|==1.10.0 gpu_py35h3435052_0|...|==1.9.0 gpu_py36h9f529ab_1], which requires
#    │     └─ cudatoolkit 8.0.* , which does not exist (perhaps a missing channel);
#    ├─ tensorflow [1.4.1|1.5.0|1.6.0|1.7.0] would require
#    │  ├─ tensorflow-base [1.6.0 |1.7.0 ], which can be installed (as previously explained);
#    │  └─ tensorflow-tensorboard [ |>=1.5.0,<1.6.0 ] with the potential options
#    │     ├─ tensorflow-tensorboard [0.4.0|1.5.1] would require
#    │     │  └─ python >=2.7,<2.8.0a0 , which can be installed;
#    │     ├─ tensorflow-tensorboard [0.4.0|1.5.1] would require
#    │     │  └─ python >=3.5,<3.6.0a0 , which can be installed;
#    │     └─ tensorflow-tensorboard [0.4.0|1.5.1] would require
#    │        └─ python >=3.6,<3.7.0a0 , which can be installed;
#    ├─ tensorflow 1.8.0 would require
#    │  └─ tensorflow-base 1.8.0  with the potential options
#    │     ├─ tensorflow-base [1.13.1|1.13.2|1.6.0|1.7.0|1.8.0], which can be installed (as previously explained);
#    │     ├─ tensorflow-base [1.6.0|1.7.0|1.8.0], which can be installed (as previously explained);
#    │     ├─ tensorflow-base [1.13.1|1.6.0|1.7.0|1.8.0], which can be installed (as previously explained);
#    │     └─ tensorflow-base [1.10.0|1.8.0|1.9.0], which cannot be installed (as previously explained);
#    └─ tensorflow 1.9.0 would require
#       └─ tensorflow-base [==1.9.0 gpu_py27h9f529ab_0|==1.9.0 gpu_py35h9f529ab_0|==1.9.0 gpu_py36h9f529ab_0], which requires
#          └─ package_has_been_revoked, which does not exist (perhaps a missing channel).
#
# Looking for: ['seaborn']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['matplotlib-venn']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch       ⣾  pkgs/main/linux-64                                            No change
# pkgs/main/noarch                                              No change
# [+] 0.1s
# pkgs/r/linux-64  ⣾
# pkgs/r/noarch    ⣾  pkgs/r/noarch                                                 No change
# pkgs/r/linux-64                                               No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['bravado']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch       ⣾  pkgs/main/noarch                                              No change
# pkgs/main/linux-64                                            No change
# pkgs/r/linux-64                                               No change
# pkgs/r/noarch                                                 No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['requests']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch       ⣾  [+] 0.1s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch       ⣾  pkgs/main/noarch                                              No change
# pkgs/r/linux-64                                               No change
# pkgs/r/noarch                                                 No change
# pkgs/main/linux-64                                            No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['requests-cache']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64                                            No change
# pkgs/main/noarch                                              No change
# pkgs/r/linux-64                                               No change
# pkgs/r/noarch                                                 No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['redo']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['suds-community']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64                                            No change
# pkgs/r/linux-64                                               No change
# pkgs/main/noarch                                              No change
# [+] 0.1s
# pkgs/r/noarch  ⣾  pkgs/r/noarch                                                 No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['beautifulsoup4']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['chembl_webresource_client']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64                                            No change
# pkgs/r/linux-64                                               No change
# pkgs/main/noarch                                              No change
# pkgs/r/noarch                                                 No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['pypdb']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ["biopython[version='<=1.77']"]
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/noarch                                              No change
# pkgs/r/noarch                                                 No change
# pkgs/main/linux-64                                            No change
# pkgs/r/linux-64                                               No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# Could not solve for environment specs
# The following packages are incompatible
# └─ biopython <=1.77  is installable with the potential options
#    ├─ biopython [1.70|1.71|...|1.76] would require
#    │  └─ python [2.7* |>=2.7,<2.8.0a0 ], which can be installed;
#    ├─ biopython [1.70|1.71|1.72] would require
#    │  └─ python [3.5* |>=3.5,<3.6.0a0 ], which can be installed;
#    ├─ biopython [1.70|1.71] would require
#    │  └─ python 3.6* , which can be installed;
#    ├─ biopython [1.70|1.71|...|1.77] would require
#    │  └─ python >=3.6,<3.7.0a0 , which can be installed;
#    ├─ biopython [1.71|1.72|...|1.77] would require
#    │  └─ python >=3.7,<3.8.0a0 , which can be installed;
#    ├─ biopython [1.74|1.75|1.76|1.77] would require
#    │  └─ python >=3.8,<3.9.0a0 , which can be installed;
#    └─ biopython 1.77 would require
#       └─ python >=3.9,<3.10.0a0 , which can be installed.
#
# Looking for: ['biopandas']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['rdkit']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['openbabel']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64                                            No change
# pkgs/r/linux-64                                               No change
# pkgs/main/noarch                                              No change
# pkgs/r/noarch                                                 No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['opencadd']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# Could not solve for environment specs
# The following package could not be installed
# └─ opencadd is installable and it requires
#    └─ biopython <=1.77  with the potential options
#       ├─ biopython [1.70|1.71|...|1.76] would require
#       │  └─ python [2.7* |>=2.7,<2.8.0a0 ], which can be installed;
#       ├─ biopython [1.70|1.71|1.72] would require
#       │  └─ python [3.5* |>=3.5,<3.6.0a0 ], which can be installed;
#       ├─ biopython [1.70|1.71] would require
#       │  └─ python 3.6* , which can be installed;
#       ├─ biopython [1.70|1.71|...|1.77] would require
#       │  └─ python >=3.6,<3.7.0a0 , which can be installed;
#       ├─ biopython [1.71|1.72|...|1.77] would require
#       │  └─ python >=3.7,<3.8.0a0 , which can be installed;
#       ├─ biopython [1.74|1.75|1.76|1.77] would require
#       │  └─ python >=3.8,<3.9.0a0 , which can be installed;
#       └─ biopython 1.77 would require
#          └─ python >=3.9,<3.10.0a0 , which can be installed.
#
# Looking for: ["biotite[version='>=0.34.0']"]
#
# conda-forge/linux-64                                        Using cache
# ...
# [+] 0.0s
# pkgs/main/linux-64                                            No change
# pkgs/r/noarch                                                 No change
# pkgs/r/linux-64                                               No change
# pkgs/main/noarch                                              No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['recommonmark']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['sphinx-autodoc-typehints']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch       ⣾  pkgs/main/linux-64                                            No change
# pkgs/r/linux-64                                               No change
# pkgs/main/noarch                                              No change
# pkgs/r/noarch                                                 No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['sphinx-copybutton']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['sphinx-gallery']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch       ⣾  pkgs/main/linux-64                                            No change
# pkgs/r/linux-64                                               No change
# pkgs/main/noarch                                              No change
# pkgs/r/noarch                                                 No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
#
# Looking for: ['autodocsumm']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed
#
# Requirement already satisfied: black-nb in /usr/local/lib/python3.10/site-packages (0.7)
# Requirement already satisfied: nbsphinx-link in /usr/local/lib/python3.10/site-packages (1.3.1)
# Requirement already satisfied: sphinxext-opengraph in /usr/local/lib/python3.10/site-packages (0.9.1)
# Requirement already satisfied: deepchem in /usr/local/lib/python3.10/site-packages (2.8.0)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.10/site-packages (from black-nb) (24.3.0)
# Requirement already satisfied: black>=21.9b0 in /usr/local/lib/python3.10/site-packages (from black[jupyter]>=21.9b0->black-nb) (24.10.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/site-packages (from black-nb) (8.1.8)
# Requirement already satisfied: nbformat>=4.4.0 in /usr/local/lib/python3.10/site-packages (from black-nb) (5.10.4)
# Requirement already satisfied: nbsphinx in /usr/local/lib/python3.10/site-packages (from nbsphinx-link) (0.9.6)
# Requirement already satisfied: sphinx>=1.8 in /usr/local/lib/python3.10/site-packages (from nbsphinx-link) (7.3.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/site-packages (from deepchem) (1.4.2)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/site-packages (from deepchem) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/site-packages (from deepchem) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/site-packages (from deepchem) (1.6.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/site-packages (from deepchem) (1.13.3)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.10/site-packages (from deepchem) (1.13.1)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.10/site-packages (from deepchem) (2024.9.4)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/site-packages (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/site-packages (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb) (23.2)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/site-packages (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/site-packages (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb) (4.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/site-packages (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/site-packages (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb) (4.12.2)
# Requirement already satisfied: ipython>=7.8.0 in /usr/local/lib/python3.10/site-packages (from black[jupyter]>=21.9b0->black-nb) (8.31.0)
# Requirement already satisfied: tokenize-rt>=3.2.0 in /usr/local/lib/python3.10/site-packages (from black[jupyter]>=21.9b0->black-nb) (6.1.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/site-packages (from nbformat>=4.4.0->black-nb) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/site-packages (from nbformat>=4.4.0->black-nb) (4.3.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/site-packages (from nbformat>=4.4.0->black-nb) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.10/site-packages (from nbformat>=4.4.0->black-nb) (5.14.3)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.0.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.1.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.0.0)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (3.0.3)
# Requirement already satisfied: Pygments>=2.14 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.19.1)
# Requirement already satisfied: docutils<0.22,>=0.18.1 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.0 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.2.0)
# Requirement already satisfied: babel>=2.9 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.16.0)
# Requirement already satisfied: alabaster~=0.7.14 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (1.4.1)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.31.0)
# Requirement already satisfied: nbconvert!=5.4,>=5.3 in /usr/local/lib/python3.10/site-packages (from nbsphinx->nbsphinx-link) (7.16.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/site-packages (from pandas->deepchem) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas->deepchem) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/site-packages (from pandas->deepchem) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/site-packages (from scikit-learn->deepchem) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/site-packages (from sympy->deepchem) (1.3.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (5.1.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (3.0.48)
# Requirement already satisfied: stack_data in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/site-packages (from Jinja2>=3.0->sphinx>=1.8->nbsphinx-link) (3.0.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.4.0->black-nb) (0.20.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (3.1.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (1.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->deepchem) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests>=2.25.0->sphinx>=1.8->nbsphinx-link) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests>=2.25.0->sphinx>=1.8->nbsphinx-link) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests>=2.25.0->sphinx>=1.8->nbsphinx-link) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests>=2.25.0->sphinx>=1.8->nbsphinx-link) (2024.12.14)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.8.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/site-packages (from nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (7.4.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (2.5)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/site-packages (from stack_data->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/site-packages (from stack_data->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (3.0.0)
# Requirement already satisfied: pure_eval in /usr/local/lib/python3.10/site-packages (from stack_data->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.2.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (1.6.0)
# Requirement already satisfied: pyzmq>=23.0 in /usr/local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (6.4.2)

# %%
import time
import random
from pathlib import Path

import pandas as pd
import numpy
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit import DataStructs
from rdkit.ML.Cluster import Butina
from rdkit.Chem import Draw
from rdkit.Chem import rdFingerprintGenerator

# %%
# Load and have a look into data
# Filtered data taken from **Part-2**
compound_df = pd.read_csv(
    "/content/ro5_properties.csv",
    index_col=0,
)
print("Dataframe shape:", compound_df.shape)
compound_df.head()
# Out:
# Dataframe shape: (43, 10)
#   molecule_chembl_id  IC50 units  \
# 0       CHEMBL502775   332    nM
# 1      CHEMBL1481974   578    nM
# 2       CHEMBL471004   634    nM
# 3         CHEMBL6246   760    nM
# 4      CHEMBL1409373  1970    nM
#
#                                               smiles     pIC50  \
# 0      O=C(O)/C=C/c1c2ccc(=O)c(O)c-2oc2c(O)c(O)ccc12  6.478862
# 1         O=C(O)CCc1c2ccc(=O)c(O)c-2oc2c(O)c(O)ccc12  6.238072
# 2  CC1C2C=CC1C(c1c3ccc(=O)c(O)c-3oc3c(O)c(O)ccc13...  6.197911
# 3         O=c1oc2c(O)c(O)cc3c(=O)oc4c(O)c(O)cc1c4c23  6.119186
# 4           NS(=O)(=O)c1ccc2c(c1)C1C=CCC1C(C(=O)O)N2  5.705534
#
#    molecular_weight  n_hba  n_hbd    logp  ro5_fulfilled
# 0        314.042653      6      4  2.1124           True
# 1        316.058303      6      4  2.0318           True
# 2        394.105253      6      4  3.2509           True
# 3        302.006267      8      4  1.3128           True
# 4        294.067428      4      3  0.8724           True

# %%
# Create molecules from SMILES and store in array
compounds = []
# .itertuples() returns a (index, column1, column2, ...) tuple per row
#  don't need index so used _ instead
# I sliced the dataframe to only the two columns I need now
for _, chembl_id, smiles in compound_df[["molecule_chembl_id", "smiles"]].itertuples():
    compounds.append((Chem.MolFromSmiles(smiles), chembl_id))
compounds[:5]
# Out:
# [(<rdkit.Chem.rdchem.Mol at 0x7de62a990430>, 'CHEMBL502775'),
#  (<rdkit.Chem.rdchem.Mol at 0x7de62a9906d0>, 'CHEMBL1481974'),
#  (<rdkit.Chem.rdchem.Mol at 0x7de62a9907b0>, 'CHEMBL471004'),
#  (<rdkit.Chem.rdchem.Mol at 0x7de62a990820>, 'CHEMBL6246'),
#  (<rdkit.Chem.rdchem.Mol at 0x7de62a990890>, 'CHEMBL1409373')]

# %%
# Create fingerprints for all molecules
rdkit_gen = rdFingerprintGenerator.GetRDKitFPGenerator(maxPath=5)
fingerprints = [rdkit_gen.GetFingerprint(mol) for mol, idx in compounds]

# How many compounds/fingerprints do I have?
print("Number of compounds converted:", len(fingerprints))
print("Fingerprint length per compound:", len(fingerprints[0]))
# NBVAL_CHECK_OUTPUT
# Out:
# Number of compounds converted: 43
# Fingerprint length per compound: 2048

# %% [markdown]
# #### Calculation for Tanimoto similarity and distance matrix
# Now that I generated fingerprints, I moved on to the next step: The identification of potential cluster centroids.  For this, I defined functions to calculate the Tanimoto similarity and distance matrix.

# %%
def tanimoto_distance_matrix(fp_list):
    """Calculate distance matrix for fingerprint list"""
    dissimilarity_matrix = []
    # I deliberately skipped the first and last items in the list
    # because I don't need to compare them against themselves
    for i in range(1, len(fp_list)):
        # Compare the current fingerprint against all the previous ones in the list
        similarities = DataStructs.BulkTanimotoSimilarity(fp_list[i], fp_list[:i])
        # Since I need a distance matrix, calculated 1-x for every element in similarity matrix
        dissimilarity_matrix.extend([1 - x for x in similarities])
    return dissimilarity_matrix

# %% [markdown]
# See also [[Rdkit-discuss] BulkTanimotoSimilarity](https://sourceforge.net/p/rdkit/mailman/rdkit-discuss/thread/663770d4-b809-c599-e379-31f57380a1d0%40gmail.com/#msg36335970).

# %%
# Example: Calculate single similarity of two fingerprints
# NBVAL_CHECK_OUTPUT
sim = DataStructs.TanimotoSimilarity(fingerprints[0], fingerprints[1])
print(f"Tanimoto similarity: {sim:.2f}, distance: {1-sim:.2f}")
# Out:
# Tanimoto similarity: 0.79, distance: 0.21

# %%
# Example: Calculate distance matrix (distance = 1-similarity)
tanimoto_distance_matrix(fingerprints)[0:5]
# Out:
# [0.21479713603818618,
#  0.3392156862745098,
#  0.2093023255813954,
#  0.6748166259168704,
#  0.6812652068126521]

# %%
# Side note: That looked like a list and not a matrix.
# But it is a triangular similarity matrix in the form of a list
n = len(fingerprints)

# Calculate number of elements in triangular matrix via n*(n-1)/2
elem_triangular_matr = (n * (n - 1)) / 2
print(
    f"Elements in the triangular matrix ({elem_triangular_matr:.0f}) ==",
    f"tanimoto_distance_matrix(fingerprints) ({len(tanimoto_distance_matrix(fingerprints))})",
)
# NBVAL_CHECK_OUTPUT
# Out:
# Elements in the triangular matrix (903) == tanimoto_distance_matrix(fingerprints) (903)

# %% [markdown]
# #### Clustering molecules: Centroids and exclusion spheres
# In this part, I clustered the molecules and look at the results.

# %% [markdown]
# Define a clustering function.

# %%
def cluster_fingerprints(fingerprints, cutoff=0.2):
    """Cluster fingerprints
    Parameters:
        fingerprints
        cutoff: threshold for the clustering
    """
    # Calculate Tanimoto distance matrix
    distance_matrix = tanimoto_distance_matrix(fingerprints)
    # Now cluster the data with the implemented Butina algorithm:
    clusters = Butina.ClusterData(distance_matrix, len(fingerprints), cutoff, isDistData=True)
    clusters = sorted(clusters, key=len, reverse=True)
    return clusters

# %% [markdown]
# Cluster the molecules based on their fingerprint similarity.

# %%
# Run the clustering procedure for the dataset
clusters = cluster_fingerprints(fingerprints, cutoff=0.3)

# Give a short report about the numbers of clusters and their sizes
num_clust_g1 = sum(1 for c in clusters if len(c) == 1)
num_clust_g5 = sum(1 for c in clusters if len(c) > 5)
num_clust_g25 = sum(1 for c in clusters if len(c) > 25)
num_clust_g100 = sum(1 for c in clusters if len(c) > 100)

print("total # clusters: ", len(clusters))
print("# clusters with only 1 compound: ", num_clust_g1)
print("# clusters with >5 compounds: ", num_clust_g5)
print("# clusters with >25 compounds: ", num_clust_g25)
print("# clusters with >100 compounds: ", num_clust_g100)
# NBVAL_CHECK_OUTPUT
# Out:
# total # clusters:  16
# # clusters with only 1 compound:  13
# # clusters with >5 compounds:  1
# # clusters with >25 compounds:  0
# # clusters with >100 compounds:  0

# %%
# Plot the size of the clusters
fig, ax = plt.subplots(figsize=(15, 4))
ax.set_xlabel("Cluster index")
ax.set_ylabel("Number of molecules")
ax.bar(range(1, len(clusters) + 1), [len(c) for c in clusters], lw=5);

# %% [markdown]
# #### How to pick a reasonable cutoff?
# Since the clustering result depends on the threshold chosen by the user, I will have a closer look on the choice of a cutoff.

# %%
for cutoff in numpy.arange(0.0, 1.0, 0.2):
    clusters = cluster_fingerprints(fingerprints, cutoff=cutoff)
    fig, ax = plt.subplots(figsize=(15, 4))
    ax.set_title(f"Threshold: {cutoff:3.1f}")
    ax.set_xlabel("Cluster index")
    ax.set_ylabel("Number of molecules")
    ax.bar(range(1, len(clusters) + 1), [len(c) for c in clusters], lw=5)
    display(fig)

# %% [markdown]
# As you can see, the higher the threshold (distance cutoff), the more molecules are considered as similar and, therefore, clustered into less clusters.
# The lower the threshold, the more small clusters and "singletons" appear.
#
# > The smaller the distance value cut-off, the more similar the compounds are required to be to belong to one cluster.
#
# Looking at the plots above, I decided to choose a distance threshold of `0.2`. There are not many singletons and the cluster sizes don't have an extreme but smooth distribution.

# %%
cutoff = 0.2
clusters = cluster_fingerprints(fingerprints, cutoff=cutoff)

# Plot the size of the clusters - save plot
fig, ax = plt.subplots(figsize=(15, 4))
ax.set_xlabel("Cluster index")
ax.set_ylabel("# molecules")
ax.bar(range(1, len(clusters) + 1), [len(c) for c in clusters])
ax.set_title(f"Threshold: {cutoff:3.1f}")
fig.savefig(
    f"cluster_dist_cutoff_{cutoff:4.2f}.png",
    dpi=300,
    bbox_inches="tight",
    transparent=True,
)

print(
    f"Number of clusters: {len(clusters)} from {len(compounds)} molecules at distance cut-off {cutoff:.2f}"
)
print("Number of molecules in largest cluster:", len(clusters[0]))
print(
    f"Similarity between two random points in same cluster: {DataStructs.TanimotoSimilarity(fingerprints[clusters[0][0]], fingerprints[clusters[0][1]]):.2f}"
)
print(
    f"Similarity between two random points in different cluster: {DataStructs.TanimotoSimilarity(fingerprints[clusters[0][0]], fingerprints[clusters[1][0]]):.2f}"
)
# Out:
# Number of clusters: 19 from 43 molecules at distance cut-off 0.20
# Number of molecules in largest cluster: 20
# Similarity between two random points in same cluster: 0.81
# Similarity between two random points in different cluster: 0.75

# %% [markdown]
# ### Visualizing the clusters

# %% [markdown]
# #### 10 examples from largest cluster
#
# Now, let's have a closer look at the first 10 molecular structures of the first/largest clusters.

# %%
print("Ten molecules from largest cluster:")
# Draw molecules
Draw.MolsToGridImage(
    [compounds[i][0] for i in clusters[0][:10]],
    legends=[compounds[i][1] for i in clusters[0][:10]],
    molsPerRow=5,
)
# Out:
# Ten molecules from largest cluster:

# %%
# Save molecules from largest cluster so other talktorials can use it
sdf_path = str("molecule_set_largest_cluster.sdf")
sdf = Chem.SDWriter(sdf_path)
for index in clusters[0]:
    mol, label = compounds[index]
    # Add label to metadata
    mol.SetProp("_Name", label)
    sdf.write(mol)
sdf.close()

# %% [markdown]
# #### 10 examples from second largest cluster

# %%
print("Ten molecules from second largest cluster:")
# Draw molecules
Draw.MolsToGridImage(
    [compounds[i][0] for i in clusters[1][:10]],
    legends=[compounds[i][1] for i in clusters[1][:10]],
    molsPerRow=5,
)
# Out:
# Ten molecules from second largest cluster:

# %% [markdown]
# The first ten molecules in the respective clusters look indeed similar to each other and many share a common scaffold (visually detected).

# %% [markdown]
# #### Examples from first 10 clusters
#
# For comparison, cluster centers of the first 10 clusters:

# %%
print("Ten molecules from first 10 clusters:")
# Draw molecules
Draw.MolsToGridImage(
    [compounds[clusters[i][0]][0] for i in range(10)],
    legends=[compounds[clusters[i][0]][1] for i in range(10)],
    molsPerRow=5,
)
# Out:
# Ten molecules from first 10 clusters:

# %% [markdown]
# Save cluster centers from first 3 clusters as SVG file.

# %%
# Generate image
img = Draw.MolsToGridImage(
    [compounds[clusters[i][0]][0] for i in range(0, 3)],
    legends=[f"Cluster {i}" for i in range(1, 4)],
    subImgSize=(200, 200),
    useSVG=True,
)

# Patch RAW svg data: convert non-transparent to transparent background and set font size
molsvg = img.data.replace("opacity:1.0", "opacity:0.0").replace("12px", "20px")

# Save altered SVG data to file
with open("cluster_representatives.svg", "w") as f:
    f.write(molsvg)

# %% [markdown]
# While still some similarity is visible, clearly, the centroids from the different clusters look more dissimilar then the compounds within one cluster.

# %% [markdown]
# #### Intra-cluster Tanimoto similarities
#
# Intra-cluster Tanimoto similarities:

# %%
def intra_tanimoto(fps_clusters):
    """Function to compute Tanimoto similarity for all pairs of fingerprints in each cluster"""
    intra_similarity = []
    # Calculate intra similarity per cluster
    for cluster in fps_clusters:
        # Tanimoto distance matrix function converted to similarity matrix (1-distance)
        intra_similarity.append([1 - x for x in tanimoto_distance_matrix(cluster)])
    return intra_similarity

# %%
# Recompute fingerprints for 10 first clusters
mol_fps_per_cluster = []
for cluster in clusters[:20]:
    mol_fps_per_cluster.append([rdkit_gen.GetFingerprint(compounds[i][0]) for i in cluster])

# Compute intra-cluster similarity
intra_sim = intra_tanimoto(mol_fps_per_cluster)

# %%
# Violin plot with intra-cluster similarity

fig, ax = plt.subplots(figsize=(10, 5))
indices = list(range(20))
ax.set_xlabel("Cluster index")
ax.set_ylabel("Similarity")
ax.set_xticks(indices)
ax.set_xticklabels(indices)
ax.set_yticks(numpy.arange(0.6, 1.0, 0.1))
ax.set_title("Intra-cluster Tanimoto similarity", fontsize=13)
r = ax.violinplot(intra_sim, indices, showmeans=True, showmedians=True, showextrema=False)
r["cmeans"].set_color("red")
# mean=red, median=blue
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-5813255f3fbb> in <cell line: 11>()
#       9 ax.set_yticks(numpy.arange(0.6, 1.0, 0.1))
#      10 ax.set_title("Intra-cluster Tanimoto similarity", fontsize=13)
# ---> 11 r = ax.violinplot(intra_sim, indices, showmeans=True, showmedians=True, showextrema=False)
#      12 r["cmeans"].set_color("red")
#      13 # mean=red, median=blue
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1463     def inner(ax, *args, data=None, **kwargs):
#    1464         if data is None:
# -> 1465             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1466
#    1467         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in violinplot(self, dataset, positions, vert, widths, showmeans, showextrema, showmedians, quantiles, points, bw_method)
#    8251             return kde.evaluate(coords)
#    8252
# -> 8253         vpstats = cbook.violin_stats(dataset, _kde_method, points=points,
#    8254                                      quantiles=quantiles)
#    8255         return self.violin(vpstats, positions=positions, vert=vert,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook.py in violin_stats(X, method, points, quantiles)
#    1497
#    1498         # Calculate basic stats for the distribution
# -> 1499         min_val = np.min(x)
#    1500         max_val = np.max(x)
#    1501         quantile_val = np.percentile(x, 100 * q)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in min(a, axis, out, keepdims, initial, where)
#    2951     6
#    2952     """
# -> 2953     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2954                           keepdims=keepdims, initial=initial, where=where)
#    2955
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      86                 return reduction(axis=axis, out=out, **passkwargs)
#      87
# ---> 88     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      89
#      90
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %% [markdown]
# ### Picking the final list of compounds
#
# In the following, I picked a final list of **max. 1000 compounds** as a **diverse** subset.
#
# For this, I took the cluster centroid from each cluster (i.e. the first molecule of each cluster) and then for each cluster (starting with the largest one) I took the 10 molecules (or 50% if less than 10 molecules are left in the cluster) that are most similar to the centroid, until I selected max. 1000 compounds. Thus, I have representatives of each cluster.
#
# Aim of this compound picking is to ensure the diversity for a smaller set of compounds which are proposed for testing in a confirmatory assay.
#
# > Picking procedure was adapted from [TDT tutorial notebook by S. Riniker and G. Landrum](https://github.com/sriniker/TDT-tutorial-2014/blob/master/TDT_challenge_tutorial.ipynb).
#
# As described there: the idea behind this approach is to ensure diversity (representatives of each cluster) while getting some SAR (structure-activity relationship) from the results of the confirmatory assay (groups of quite similar molecules from larger clusters retained).

# %% [markdown]
# Get cluster centers.

# %%
# Get the cluster center of each cluster (first molecule in each cluster)
cluster_centers = [compounds[c[0]] for c in clusters]
# How many cluster centers/clusters do I have?
print("Number of cluster centers:", len(cluster_centers))
# NBVAL_CHECK_OUTPUT
# Out:
# Number of cluster centers: 19

# %% [markdown]
# Sort clusters by size and molecules in each cluster by similarity.

# %%
# Sort the molecules within a cluster based on their similarity
# to the cluster center and sort the clusters based on their size
sorted_clusters = []
for cluster in clusters:
    if len(cluster) <= 1:
        continue  # Singletons
    # else:
    # Compute fingerprints for each cluster element
    sorted_fingerprints = [rdkit_gen.GetFingerprint(compounds[i][0]) for i in cluster]
    # Similarity of all cluster members to the cluster center
    similarities = DataStructs.BulkTanimotoSimilarity(
        sorted_fingerprints[0], sorted_fingerprints[1:]
    )
    # Add index of the molecule to its similarity (centroid excluded!)
    similarities = list(zip(similarities, cluster[1:]))
    # Sort in descending order by similarity
    similarities.sort(reverse=True)
    # Save cluster size and index of molecules in clusters_sort
    sorted_clusters.append((len(similarities), [i for _, i in similarities]))
    # Sort in descending order by cluster size
    sorted_clusters.sort(reverse=True)

# %% [markdown]
# Pick a maximum of 1000 compounds.

# %%
# Count selected molecules, pick cluster centers first
selected_molecules = cluster_centers.copy()
# Take 10 molecules (or a maximum of 50%) of each cluster starting with the largest one
index = 0
pending = 1000 - len(selected_molecules)
while pending > 0 and index < len(sorted_clusters):
    # Take indices of sorted clusters
    tmp_cluster = sorted_clusters[index][1]
    # If the first cluster is > 10 big then take exactly 10 compounds
    if sorted_clusters[index][0] > 10:
        num_compounds = 10
    # If smaller, take half of the molecules
    else:
        num_compounds = int(0.5 * len(tmp_cluster)) + 1
    if num_compounds > pending:
        num_compounds = pending
    # Write picked molecules and their structures into list of lists called picked_fps
    selected_molecules += [compounds[i] for i in tmp_cluster[:num_compounds]]
    index += 1
    pending = 1000 - len(selected_molecules)
print("# Selected molecules:", len(selected_molecules))
# NBVAL_CHECK_OUTPUT
# Out:
# # Selected molecules: 34

# %% [markdown]
# In case you want to save these selected molecules.

# %%
#Convert it into a DataFrame
df_selected_molecules = pd.DataFrame(selected_molecules)

# Save DataFrame to CSV file
df_selected_molecules.to_csv('selected_molecules.csv', index=False)

# %% [markdown]
# This set of diverse molecules could now be used for experimental testing.

# %% [markdown]
# ###**Additional Stuff I could do**

# %%
# Reuse old dataset
sampled_mols = compounds.copy()

# %% [markdown]
# Note that one can try out larger datasets, but data sizes larger than 10000 data points already start to consume quite some memory and time (that's why I stopped there).

# %%
# Helper function for time computation
def measure_runtime(sampled_mols):
    start_time = time.time()
    sampled_fingerprints = [rdkit_gen.GetFingerprint(m) for m, idx in sampled_mols]
    # Run the clustering with the dataset
    sampled_clusters = cluster_fingerprints(sampled_fingerprints, cutoff=0.3)
    return time.time() - start_time

# %%
len(sampled_mols)
# NBVAL_CHECK_OUTPUT

# %%
sample_sizes = [100, 500, 1000, 2000, 4000]
runtimes = []
# Take random samples with replacement
for size in sample_sizes:
    time_taken = measure_runtime(random.sample(sampled_mols, size))
    print(f"Dataset size {size}, time {time_taken:4.2f} seconds")
    runtimes.append(time_taken)

# %%
fig, ax = plt.subplots()
ax.set_title("Runtime measurement of Butina Clustering with different dataset sizes")
ax.set_xlabel("# Molecules in data set")
ax.set_ylabel("Runtime in seconds")
ax.plot(sample_sizes, runtimes, "g^");

# %% [markdown]
# Notice how the runtime is not exactly proportional to the sample size! It grows faster!
