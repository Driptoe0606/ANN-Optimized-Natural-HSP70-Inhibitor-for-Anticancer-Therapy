# %% [markdown]
# <a href="https://colab.research.google.com/github/Driptoe0606/ChemGAN-challenge/blob/master/Maximum_Common_Substructure_Part_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Search for a Maximum common substructure

# %% [markdown]
# ### Contents in *Theory*
#
# * Introduction to identification of maximum common substructure in a set of molecules
# * Detailed explanation of the FMCS algorithm

# %% [markdown]
# ### Contents in *Practical*
#
# * Load and draw molecules
# * Run the FMCS algorithm with different input parameters
# * A more diverse set: the HSP70 compounds downloaded from ChEMBL
# * Identification of MCS using interactive cut-off adaption

# %% [markdown]
# ### References
#
# * Dalke A, Hastings J., FMCS: a novel algorithm for the multiple MCS problem. [*J. Cheminf.* 2013; **5** (Suppl 1): O6](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3606201/)
# * Raymond JW., Willet P., Maximum common subgraph isomorphism algorithms for the matching of chemical structures. [*J Comput Aided Mol Des.* 2002 Jul; **16**(7):521-33](https://link.springer.com/article/10.1023/A:1021271615909)
# * [Dalke's website with info on algorithm](http://dalkescientific.com/writings/diary/archive/2012/05/12/mcs_background.html)
# * [RDKit Cookbook documentation on MCS](http://www.rdkit.org/docs/Cookbook.html#using-custom-mcs-atom-types)

# %% [markdown]
# ## Theory

# %% [markdown]
# ### Introduction to identification of maximum common substructure in a set of molecules
#
# ![Maximum common substructure, highlighted](https://github.com/volkamerlab/teachopencadd/blob/master/teachopencadd/talktorials/T006_compound_maximum_common_substructures/images/mymols.png?raw=1)
#
# The maximum common structure (MCS) is defined as the largest substructure that appears in two or more candidate molecules.
#
# * Finding the MCS = maximum common subgraph isomorphism problem
# * Has many applications in the field of cheminformatics: similarity search, hierarchical clustering, or molecule alignment
# * Advantages:
#   * Intuitive $\rightarrow$ shared structure among candidates likely to be important
#   * Provides insight into possible activity patterns
#   * Easy visualization by simply highlighting the substructure
#
# Details on MCS algorithms (see review: [*J Comput Aided Mol Des.* 2002 Jul; **16**(7):521-33](https://link.springer.com/article/10.1023/A:1021271615909))
#
# * Determining an MCS between two or more graphs is an NP-complete problem
# * Algorithms for exact determination as well as approximations exist
#   * Exact: Maximum-clique, backtracking, dynamic programming
#   * Approximate: Genetic algorithm, combinatorial optimization, fragment storage, ...
#   * Problem reduction: Simplify the molecular graphs
#
#
# Example of an implementation: [FMCS](http://dalkescientific.com/writings/diary/archive/2012/05/12/mcs_background.html) algorithm
#
# * Models MCS problem as a graph isomorphism problem
# * Based on subgraph enumeration and subgraph isomorphism testing

# %% [markdown]
# ### Detailed explanation of FMCS algorithm
# As explained in [*J. Cheminf.* 2013; **5**(Suppl 1): O6](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3606201/) and the respective [RDKit FMCS documentation](https://www.rdkit.org/docs/source/rdkit.Chem.fmcs.fmcs.html).

# %% [markdown]
# #### The simplified algorithm description
#
# ```
# best_substructure = None
# pick one structure in the set as query, all other as targets
# for each substructure in the query:
#     convert into a SMARTS string based on the desired match properties
#     if SMARTS pattern exists in all of the targets:
#         then it is a common substructure
#         keep track of the maximum of such substructure
# ```
#
# This simple approach alone will usually take a long time, but there are certain tricks used to speed up the run time.

# %% [markdown]
# #### Tricks to speed up the run time
#
# <img src="https://github.com/volkamerlab/teachopencadd/blob/master/teachopencadd/talktorials/T006_compound_maximum_common_substructures/images/speed_tricks.jpg?raw=1" width=800 />
#
# #### A) Bond elimination
#
#
# * Remove bonds that cannot be part of the MCS
# * Atom and bond type information has to be present in every input structure
# * Bond type: string consisting of SMARTS of the first atom, the bond and the second atom
# * Exclude all bond types not present in all input structures, delete respective edges
# * Result: fragmented structures with all atom information, but fewer edges (bonds)
#
# #### B) Use the structure with the smallest largest fragment as the query
#
# * Heuristic approach:
#     * Find largest fragment of each input structure
#     * Sort input structures ascending by number of bonds in largest fragment
#     * Solve ties with number of atoms or input order as alternative
# * The structure with the smallest largest fragment becomes the query structure
# * The ones from the other input structures are the targets
#
# #### C) Use a breadth-first search (BFS) and a priority queue to enumerate the fragment subgraphs
#
# __C1__
# * Enumeration based on growing a so called seed
# * Seed: atoms/bonds in current subgraph, exclusion set (bonds not applicable for growth)
# * To prevent redundancy:
#     * Initial seed is first bond in the fragment, can potentially grow to size of whole fragment
#     * Second seed is second bond, is excluded from using the first bond
#     * Third seed starts from the third bond, excluded from using the first and second
#     * ...
#
# __C2__
# * Seed grows along connected bonds (not in exclusions set or already in seed)
# * All growing possibilities are considered at every step
# * E.g. if there are N possible bonds for extension, $2^{N-1}$ possible new seeds are added to queue
# * Enumeration ends when there are no new bonds to add to subgraph (exclude seed from queue)
# * Largest seed will be processed first
#
# #### D) Prune seeds not present in all of the other structures
#
# * At each growth state $\rightarrow$ check if new seed exists in all other structures
# * Else: Exclude seed from queue
#
# #### E) Prune seeds without sufficient growing potential
#
# * Evaluation of growth potential from exclusion list and possible edges for extension
# * If potential smaller than current best subgraph  $\rightarrow$  exclude seed from queue
#
# Utilizing these approaches it is then trivial to keep track of the largest subgraph which corresponds to the maximum common substructure.

# %%
#Install Conda - Kernal Restart will take place
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# Install mamba
# !conda install -c conda-forge mamba -y

# Use mamba to install packages
# !mamba install -c conda-forge -c defaults python=3.8 -y
# !mamba install -c conda-forge -c defaults pip -y
# !mamba install -c conda-forge -c defaults jupyterlab=3 -y
# !mamba install -c conda-forge -c defaults jsonschema=4.3.0 -y
# !mamba install -c conda-forge -c defaults nglview=3 -y
# !mamba install -c conda-forge -c defaults ipywidgets=7.75 -y
# !mamba install -c conda-forge -c defaults jupyter_client=7.4.9 -y
# !mamba install -c conda-forge -c defaults 'numpy<1.24' -y
# !mamba install -c conda-forge -c defaults scikit-learn -y
# !mamba install -c conda-forge -c defaults 'tensorflow<=2.6' -y
# !mamba install -c conda-forge -c defaults seaborn -y
# !mamba install -c conda-forge -c defaults matplotlib-venn -y
# !mamba install -c conda-forge -c defaults bravado -y
# !mamba install -c conda-forge -c defaults requests -y
# !mamba install -c conda-forge -c defaults requests-cache -y
# !mamba install -c conda-forge -c defaults redo -y
# !mamba install -c conda-forge -c defaults suds-community -y
# !mamba install -c conda-forge -c defaults beautifulsoup4 -y
# !mamba install -c conda-forge -c defaults chembl_webresource_client -y
# !mamba install -c conda-forge -c defaults pypdb -y
# !mamba install -c conda-forge -c defaults 'biopython<=1.77' -y
# !mamba install -c conda-forge -c defaults biopandas -y
# !mamba install -c conda-forge -c defaults rdkit -y
# !mamba install -c conda-forge -c defaults openbabel -y
# !mamba install -c conda-forge -c defaults opencadd -y
# !mamba install -c conda-forge -c defaults 'biotite>=0.34.0' -y
# !mamba install -c conda-forge -c defaults smina -y
# !mamba install -c conda-forge -c defaults 'mdanalysis>=1.0.0' -y
# !mamba install -c conda-forge -c defaults mdtraj -y
# !mamba install -c conda-forge -c defaults plip -y
# !mamba install -c conda-forge -c defaults openmm -y
# !mamba install -c conda-forge -c defaults 'mkl<2022' -y
# !mamba install -c pytorch pytorch==1.13.0 -y
# !mamba install -c conda-forge -c defaults pdbfixer -y
# !mamba install -c conda-forge -c defaults tqdm -y
# !mamba install -c conda-forge -c defaults lxml -y
# !mamba install -c conda-forge -c defaults kissim -y
# !mamba install -c conda-forge -c defaults pytest -y
# !mamba install -c conda-forge -c defaults pytest-xdist -y
# !mamba install -c conda-forge -c defaults pytest-cov -y
# !mamba install -c conda-forge -c defaults nbval -y
# !mamba install -c conda-forge -c defaults shyaml -y
# !mamba install -c conda-forge -c defaults 'jinja2==3.0.3' -y
# !mamba install -c conda-forge -c defaults sphinx -y
# !mamba install -c conda-forge -c defaults sphinx-material -y
# !mamba install -c conda-forge -c defaults nbsphinx -y
# !mamba install -c conda-forge -c defaults recommonmark -y
# !mamba install -c conda-forge -c defaults sphinx-autodoc-typehints -y
# !mamba install -c conda-forge -c defaults sphinx-copybutton -y
# !mamba install -c conda-forge -c defaults sphinx-gallery -y
# !mamba install -c conda-forge -c defaults autodocsumm -y

# Install pip packages
# !pip install black-nb nbsphinx-link sphinxext-opengraph deepchem
# Out:
# Streaming output truncated to the last 5000 lines.
#    └─ biopython 1.77 would require
#       └─ python >=3.9,<3.10.0a0 , which can be installed.
#
# Looking for: ['biopandas']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - biopandas
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package         Version  Build         Channel         Size
# ───────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────
#
#   + mmtf-python     1.1.3  pyhd8ed1ab_0  conda-forge     26kB
#   + looseversion    1.3.0  pyhd8ed1ab_0  conda-forge     14kB
#   + biopandas       0.5.1  pyhd8ed1ab_1  conda-forge     46kB
#
#   Summary:
#
#   Install: 3 packages
#
#   Total download: 86kB
#
# ───────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading  (1)   0%
# Extracting         0%mmtf-python                                         26.0kB @ 356.4kB/s  0.1s
# [+] 0.1s
# Downloading  (2)  31%
# Extracting   (1)  ⣾  looseversion                                        14.3kB @ 139.3kB/s  0.1s
# biopandas                                           46.0kB @ 382.4kB/s  0.1s
# [+] 0.2s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['rdkit']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - rdkit
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                        Version  Build               Channel           Size
# ──────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────
#
#   + libexpat                       2.6.4  h5888daf_0          conda-forge       73kB
#   + pixman                        0.44.2  h29eaf8c_0          conda-forge      381kB
#   + libxcrypt                     4.4.36  hd590300_1          conda-forge      100kB
#   + liblzma                        5.6.3  hb9d3cd8_1          conda-forge      111kB
#   + libntlm                          1.8  hb9d3cd8_0          conda-forge       33kB
#   + xorg-libice                    1.1.2  hb9d3cd8_0          conda-forge       59kB
#   + pcre2                          10.44  hba22ea6_2          conda-forge      952kB
#   + xorg-libx11                   1.8.10  h4f16b4b_1          conda-forge      838kB
#   + fontconfig                    2.15.0  h7e30c49_1          conda-forge      266kB
#   + libboost                      1.86.0  h6c02f8c_3          conda-forge        3MB
#   + cyrus-sasl                    2.1.27  h54b06d7_7          conda-forge      220kB
#   + xorg-libsm                     1.2.5  he73a12e_0          conda-forge       27kB
#   + libglib                       2.82.2  h2ff4ddf_0          conda-forge        4MB
#   + xorg-libxrender               0.9.12  hb9d3cd8_0          conda-forge       33kB
#   + xorg-libxext                   1.3.6  hb9d3cd8_0          conda-forge       50kB
#   + openldap                       2.6.9  he970967_0          conda-forge      784kB
#   + chardet                        5.2.0  py310hff52083_2     conda-forge      243kB
#   + libboost-python               1.86.0  py310ha2bacc8_3     conda-forge      120kB
#   + sqlalchemy                    2.0.37  py310ha75aee5_0     conda-forge        3MB
#   + libpq                           17.2  h3b95a9b_1          conda-forge        3MB
#   + font-ttf-dejavu-sans-mono       2.37  hab24e00_0          conda-forge      397kB
#   + font-ttf-inconsolata           3.000  h77eed37_0          conda-forge       97kB
#   + font-ttf-source-code-pro       2.038  h77eed37_0          conda-forge      701kB
#   + font-ttf-ubuntu                 0.83  h77eed37_3          conda-forge        2MB
#   + freetype-py                    2.3.0  pyhd8ed1ab_0        conda-forge       59kB
#   + fonts-conda-forge                  1  0                   conda-forge        4kB
#   + fonts-conda-ecosystem              1  0                   conda-forge        4kB
#   + cairo                         1.18.2  h3394656_1          conda-forge      979kB
#   + pycairo                       1.27.0  py310h25ff670_0     conda-forge      116kB
#   + librdkit                   2024.09.4  h84b0b3c_0          conda-forge        9MB
#   + rlpycairo                      0.2.0  pyhd8ed1ab_0        conda-forge       15kB
#   + reportlab                      4.2.5  py310ha75aee5_0     conda-forge        2MB
#   + rdkit                      2024.09.4  py310hcd13295_0     conda-forge       20MB
#
#   Change:
# ──────────────────────────────────────────────────────────────────────────────────────
#
#   - python                       3.10.13  hd12c33a_0_cpython  conda-forge     Cached
#   + python                       3.10.13  hd12c33a_1_cpython  conda-forge       26MB
#
#   Reinstall:
# ──────────────────────────────────────────────────────────────────────────────────────
#
#   o tk                            8.6.13  noxft_h4845f30_101  conda-forge     Cached
#   o libnghttp2                    1.58.0  h47da74e_1          conda-forge     Cached
#
#   Upgrade:
# ──────────────────────────────────────────────────────────────────────────────────────
#
#   - icu                             73.2  h59595ed_0          conda-forge     Cached
#   + icu                             75.1  he02047a_0          conda-forge       12MB
#   - krb5                          1.21.2  h659d440_0          conda-forge     Cached
#   + krb5                          1.21.3  h659f571_0          conda-forge        1MB
#   - libzlib                       1.2.13  hd590300_5          conda-forge     Cached
#   + libzlib                        1.3.1  hb9d3cd8_2          conda-forge       61kB
#   - lz4-c                          1.9.4  hcb278e6_0          conda-forge     Cached
#   + lz4-c                         1.10.0  h5888daf_1          conda-forge      167kB
#   - libxcb                          1.15  h0b41bf4_0          conda-forge     Cached
#   + libxcb                        1.17.0  h8a09558_0          conda-forge      396kB
#   - libssh2                       1.11.0  h0841786_0          conda-forge     Cached
#   + libssh2                       1.11.1  hf672d98_0          conda-forge      304kB
#   - libsqlite                     3.44.2  h2797004_0          conda-forge     Cached
#   + libsqlite                     3.47.2  hee588c1_0          conda-forge      874kB
#   - libsolv                       0.7.27  hfc55251_0          conda-forge     Cached
#   + libsolv                       0.7.30  h3509ff9_0          conda-forge      471kB
#   - libpng                        1.6.43  h2797004_0          conda-forge     Cached
#   + libpng                        1.6.45  h943b412_0          conda-forge      289kB
#   - libxml2                       2.12.3  h232c23b_0          conda-forge     Cached
#   + libxml2                       2.13.5  h8d12d68_1          conda-forge      691kB
#   - libarchive                     3.7.2  h2aa1ff5_1          conda-forge     Cached
#   + libarchive                     3.7.7  h4585015_3          conda-forge      878kB
#   - pillow                        10.3.0  py310hf73ecf8_0     conda-forge     Cached
#   + pillow                        10.4.0  py310he228d35_1     conda-forge       43MB
#
#   Summary:
#
#   Install: 33 packages
#   Change: 1 packages
#   Reinstall: 2 packages
#   Upgrade: 12 packages
#
#   Total download: 137MB
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading  (1)   0%
# Extracting         0%libzlib                                             61.0kB @ 869.3kB/s  0.1s
# lz4-c                                              167.1kB @   1.9MB/s  0.1s
# [+] 0.1s
# Downloading  (5)   1%
# Extracting   (2)  ⣾  xorg-libice                                         58.6kB @ 512.6kB/s  0.0s
# krb5                                                 1.4MB @  11.8MB/s  0.1s
# libxcb                                             395.9kB @   3.0MB/s  0.1s
# libsqlite                                          873.6kB @   5.2MB/s  0.1s
# fontconfig                                         265.6kB @   1.6MB/s  0.1s
# xorg-libx11                                        837.5kB @   4.8MB/s  0.1s
# [+] 0.2s
# Downloading  (5)   8%
# Extracting   (7)  ⣾  xorg-libxext                                        50.1kB @ 231.1kB/s  0.1s
# libarchive                                         878.0kB @   3.3MB/s  0.1s
# icu                                                 12.1MB @  42.4MB/s  0.3s
# libglib                                              3.9MB @  13.6MB/s  0.2s
# [+] 0.3s
# Downloading  (5)  16%
# Extracting   (9)  ⣾  font-ttf-inconsolata                                96.5kB @ 314.1kB/s  0.1s
# freetype-py                                         58.9kB @ 185.9kB/s  0.0s
# rlpycairo                                           14.9kB @  42.4kB/s  0.1s
# libexpat                                            73.3kB @ 207.0kB/s  0.0s
# cairo                                              978.9kB @   2.7MB/s  0.1s
# liblzma                                            111.1kB @ 283.5kB/s  0.1s
# [+] 0.4s
# Downloading  (5)  23%
# Extracting  (13)  ⣾  libsolv                                            470.8kB @   1.2MB/s  0.1s
# libssh2                                            304.3kB @ 732.8kB/s  0.1s
# xorg-libsm                                          27.2kB @  65.3kB/s  0.1s
# openldap                                           784.5kB @   1.7MB/s  0.1s
# fonts-conda-ecosystem                                3.7kB @   7.7kB/s  0.1s
# font-ttf-source-code-pro                           700.8kB @   1.5MB/s  0.1s
# [+] 0.5s
# Downloading  (5)  31%
# Extracting  (19)  ⣾  libxcrypt                                          100.4kB @ 191.4kB/s  0.0s
# libpng                                             289.4kB @ 535.6kB/s  0.1s
# sqlalchemy                                           2.8MB @   5.2MB/s  0.1s
# reportlab                                            2.4MB @   4.2MB/s  0.1s
# [+] 0.6s
# Downloading  (5)  37%
# Extracting  (22)  ⣾  cyrus-sasl                                         219.5kB @ 359.7kB/s  0.1s
# pycairo                                            116.2kB @ 181.7kB/s  0.1s
# libpq                                                2.7MB @   4.0MB/s  0.1s
# [+] 0.7s
# Downloading  (5)  54%
# Extracting  (24)  ⣾  chardet                                            243.4kB @ 330.3kB/s  0.1s
# pixman                                             381.1kB @ 499.0kB/s  0.2s
# [+] 0.8s
# Downloading  (5)  60%
# Extracting  (26)  ⣾  libboost                                             2.9MB @   3.6MB/s  0.2s
# [+] 0.9s
# Downloading  (5)  65%
# Extracting  (26)  ⣾  font-ttf-ubuntu                                      1.6MB @   1.7MB/s  0.2s
# libxml2                                            690.6kB @ 742.9kB/s  0.1s
# pillow                                              42.7MB @  44.1MB/s  0.8s
# fonts-conda-forge                                    4.1kB @   4.2kB/s  0.1s
# [+] 1.0s
# Downloading  (5)  70%
# Extracting  (30)  ⣾  font-ttf-dejavu-sans-mono                          397.4kB @ 397.3kB/s  0.1s
# libboost-python                                    120.5kB @ 118.8kB/s  0.0s
# libntlm                                             33.4kB @  31.4kB/s  0.1s
# xorg-libxrender                                     33.0kB @  31.0kB/s  0.1s
# [+] 1.1s
# Downloading  (4)  75%
# Extracting  (30)  ⣾  pcre2                                              952.3kB @ 859.2kB/s  0.1s
# [+] 1.2s
# Downloading  (3)  81%
# Extracting  (33)  ⣾  [+] 1.3s
# Downloading  (3)  87%
# Extracting  (33)  ⣾  [+] 1.4s
# Downloading  (3)  94%
# Extracting  (32)  ⣾  librdkit                                             8.6MB @   6.1MB/s  0.4s
# python                                              25.7MB @  17.6MB/s  0.9s
# [+] 1.5s
# Downloading  (1) 100%
# Extracting  (34)  ⣾  rdkit                                               19.5MB @  13.0MB/s  0.7s
# [+] 1.6s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 1.7s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 1.8s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 1.9s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 2.0s
# Downloading      100%
# Extracting  (30)  ⣾  [+] 2.1s
# Downloading      100%
# Extracting  (30)  ⣾  [+] 2.2s
# Downloading      100%
# Extracting  (29)  ⣾  [+] 2.3s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 2.4s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 2.5s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 2.6s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 2.7s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 2.8s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 2.9s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 3.0s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 3.1s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 3.2s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 3.3s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 3.4s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 3.5s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 3.6s
# Downloading      100%
# Extracting  (19)  ⣾  [+] 3.7s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3.8s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 3.9s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 4.0s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 4.1s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 4.2s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 4.3s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 4.4s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 4.5s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 4.6s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 4.7s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 4.8s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 4.9s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 5.0s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 5.1s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 5.2s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 5.3s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 5.4s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 5.5s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 5.6s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 5.7s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 5.8s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 5.9s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 6.0s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 6.1s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 6.2s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 6.3s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 6.4s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 6.5s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 6.6s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 6.7s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 6.8s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 6.9s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 7.0s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 7.1s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 7.2s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 7.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.5s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 7.6s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 7.7s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 7.8s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 7.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 8.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.3s
# Downloading      100%
# Extracting       100%
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['openbabel']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/noarch                                              No change
# pkgs/main/linux-64                                            No change
# pkgs/r/linux-64                                               No change
# pkgs/r/noarch                                                 No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - openbabel
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package      Version  Build            Channel         Size
# ───────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────
#
#   + openbabel    3.1.1  py310hbff9852_9  conda-forge      5MB
#
#   Summary:
#
#   Install: 1 packages
#
#   Total download: 5MB
#
# ───────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%[+] 0.1s
# Downloading  (1)   0%
# Extracting         0%openbabel                                            5.2MB @  31.1MB/s  0.2s
# [+] 0.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 0.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 0.4s
# Downloading      100%
# Extracting       100%
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['opencadd']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# Could not solve for environment specs
# The following package could not be installed
# └─ opencadd is installable and it requires
#    └─ biopython <=1.77  with the potential options
#       ├─ biopython [1.70|1.71|...|1.76] would require
#       │  └─ python [2.7* |>=2.7,<2.8.0a0 ], which can be installed;
#       ├─ biopython [1.70|1.71|1.72] would require
#       │  └─ python [3.5* |>=3.5,<3.6.0a0 ], which can be installed;
#       ├─ biopython [1.70|1.71] would require
#       │  └─ python 3.6* , which can be installed;
#       ├─ biopython [1.70|1.71|...|1.77] would require
#       │  └─ python >=3.6,<3.7.0a0 , which can be installed;
#       ├─ biopython [1.71|1.72|...|1.77] would require
#       │  └─ python >=3.7,<3.8.0a0 , which can be installed;
#       ├─ biopython [1.74|1.75|1.76|1.77] would require
#       │  └─ python >=3.8,<3.9.0a0 , which can be installed;
#       └─ biopython 1.77 would require
#          └─ python >=3.9,<3.10.0a0 , which can be installed.
#
# Looking for: ["biotite[version='>=0.34.0']"]
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - biotite[version='>=0.34.0']
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package     Version  Build            Channel           Size
# ────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────
#
#   + biotraj     1.2.2  py310hf71b8c6_0  conda-forge        4MB
#   + networkx    3.4.2  pyh267e887_2     conda-forge        1MB
#   + biotite     1.1.0  py310hf71b8c6_1  conda-forge       47MB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────
#
#   - numpy      1.23.5  py310h53a5b5f_0  conda-forge     Cached
#   + numpy       2.2.1  py310h5851e9f_0  conda-forge     Cached
#
#   Summary:
#
#   Install: 3 packages
#   Upgrade: 1 packages
#
#   Total download: 51MB
#
# ────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%networkx                                             1.3MB @  15.3MB/s  0.1s
# [+] 0.1s
# Downloading  (2)   3%
# Extracting   (1)  ⣾  biotraj                                              3.6MB @  25.5MB/s  0.1s
# [+] 0.2s
# Downloading  (1)  35%
# Extracting   (2)  ⣾  [+] 0.3s
# Downloading  (1)  56%
# Extracting   (1)  ⣾  [+] 0.4s
# Downloading  (1)  88%
# Extracting        67%biotite                                             46.6MB @ 114.1MB/s  0.4s
# [+] 0.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 0.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 0.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 0.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 0.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.6s
# Downloading      100%
# Extracting       100%
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['smina']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch       ⣾  pkgs/main/noarch                                              No change
# pkgs/r/noarch                                                 No change
# pkgs/r/linux-64                                               No change
# pkgs/main/linux-64                                            No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Could not solve for environment specs
# The following packages are incompatible
# ├─ librdkit is installable with the potential options
# │  ├─ librdkit 2024.09.4 would require
# │  │  └─ cairo >=1.18.2,<2.0a0 , which requires
# │  │     └─ icu >=75.1,<76.0a0 , which can be installed;
# │  ├─ librdkit [2024.03.5|2024.03.6] would require
# │  │  └─ libboost >=1.84.0,<1.85.0a0  with the potential options
# │  │     ├─ libboost [1.84.0|1.86.0] would require
# │  │     │  └─ icu >=75.1,<76.0a0 , which can be installed;
# │  │     └─ libboost 1.84.0 would require
# │  │        └─ icu >=73.2,<74.0a0 , which conflicts with any installable versions previously reported;
# │  └─ librdkit [2024.03.6|2024.09.1|2024.09.2|2024.09.3] would require
# │     └─ libboost >=1.86.0,<1.87.0a0  with the potential options
# │        ├─ libboost [1.84.0|1.86.0], which can be installed (as previously explained);
# │        └─ libboost 1.86.0 would require
# │           └─ boost-cpp <0.0a0 , which can be installed;
# └─ smina is not installable because there are no viable options
#    ├─ smina 2020.12.10 would require
#    │  └─ boost-cpp >=1.74.0,<1.74.1.0a0  but there are no viable options
#    │     ├─ boost-cpp 1.74.0 would require
#    │     │  └─ icu >=68.1,<69.0a0 , which conflicts with any installable versions previously reported;
#    │     ├─ boost-cpp 1.74.0 would require
#    │     │  └─ icu >=69.1,<70.0a0 , which conflicts with any installable versions previously reported;
#    │     ├─ boost-cpp 1.74.0 would require
#    │     │  └─ icu >=70.1,<71.0a0 , which conflicts with any installable versions previously reported;
#    │     └─ boost-cpp 1.74.0 would require
#    │        └─ icu >=67.1,<68.0a0 , which conflicts with any installable versions previously reported;
#    └─ smina 2020.12.10 would require
#       └─ libboost >=1.82.0,<1.83.0a0  but there are no viable options
#          ├─ libboost 1.82.0 would require
#          │  └─ icu >=72.1,<73.0a0 , which conflicts with any installable versions previously reported;
#          ├─ libboost 1.82.0 would require
#          │  └─ icu >=73.2,<74.0a0 , which conflicts with any installable versions previously reported;
#          └─ libboost 1.82.0 would require
#             └─ icu >=73.1,<74.0a0 , which conflicts with any installable versions previously reported.
#
# Looking for: ["mdanalysis[version='>=1.0.0']"]
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - mdanalysis[version='>=1.0.0']
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package            Version  Build                    Channel          Size
# ──────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────
#
#   + fasteners           0.19  pyhd8ed1ab_1             conda-forge      21kB
#   + tidynamics         1.1.2  pyhd8ed1ab_0             conda-forge      12kB
#   + mda-xdrlib         0.2.0  pyhd8ed1ab_1             conda-forge      17kB
#   + mrcfile            1.5.3  pyhd8ed1ab_1             conda-forge      39kB
#   + pyedr              0.8.0  pyhd8ed1ab_1             conda-forge     345kB
#   + griddataformats    1.0.2  pyhd8ed1ab_1             conda-forge       2MB
#   + pytng              0.3.3  py310he95d665_1          conda-forge     530kB
#   + biopython           1.84  py310hc51659f_0          conda-forge       3MB
#   + gsd                3.4.2  py310ha75aee5_0          conda-forge     247kB
#   + libgfortran-ng    14.2.0  h69a702a_1               conda-forge      54kB
#   + cftime             1.6.4  py310hf462985_1          conda-forge     249kB
#   + hdf4              4.2.15  h2a13503_7               conda-forge     757kB
#   + zlib               1.3.1  hb9d3cd8_2               conda-forge      92kB
#   + libaec             1.1.3  h59595ed_0               conda-forge      35kB
#   + libzip            1.11.2  h6991a6a_0               conda-forge     109kB
#   + snappy             1.2.1  h8bd8927_1               conda-forge      43kB
#   + hdf5              1.14.3  nompi_hdf9ad27_105       conda-forge       4MB
#   + blosc             1.21.6  he440d0b_1               conda-forge      48kB
#   + h5py              3.12.1  nompi_py310h60e0fe6_103  conda-forge       1MB
#   + libnetcdf          4.9.2  nompi_h135f659_114       conda-forge     849kB
#   + netcdf4            1.7.2  nompi_py310h9f0ad05_101  conda-forge       1MB
#   + mdanalysis         2.8.0  py310h5eaa309_0          conda-forge       5MB
#   + mdahole2-base      0.5.0  pyhd8ed1ab_1             conda-forge       4MB
#   + pathsimanalysis    1.2.0  pyhd8ed1ab_1             conda-forge      43kB
#   + waterdynamics      1.2.0  pyhd8ed1ab_1             conda-forge      31kB
#
#   Summary:
#
#   Install: 25 packages
#
#   Total download: 24MB
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading  (2)   0%
# Extracting         0%tidynamics                                          12.0kB @ 179.3kB/s  0.1s
# fasteners                                           20.7kB @ 240.3kB/s  0.1s
# mrcfile                                             38.7kB @ 447.6kB/s  0.1s
# [+] 0.1s
# Downloading  (5)   1%
# Extracting   (3)  ⣾  mda-xdrlib                                          16.5kB @ 146.6kB/s  0.1s
# pyedr                                              344.9kB @   2.9MB/s  0.1s
# cftime                                             249.1kB @   2.1MB/s  0.1s
# libzip                                             109.0kB @ 866.2kB/s  0.0s
# gsd                                                247.0kB @   1.2MB/s  0.1s
# [+] 0.2s
# Downloading  (5)   6%
# Extracting   (5)  ⣾  libnetcdf                                          849.2kB @   3.9MB/s  0.1s
# zlib                                                92.3kB @ 363.3kB/s  0.1s
# griddataformats                                      2.1MB @   8.3MB/s  0.1s
# libaec                                              35.4kB @ 137.7kB/s  0.2s
# mdahole2-base                                        3.7MB @  14.4MB/s  0.1s
# pathsimanalysis                                     43.4kB @ 147.5kB/s  0.0s
# [+] 0.3s
# Downloading  (5)  34%
# Extracting  (11)  ⣾  blosc                                               48.4kB @ 163.4kB/s  0.1s
# pytng                                              529.7kB @   1.6MB/s  0.0s
# h5py                                                 1.3MB @   3.8MB/s  0.1s
# snappy                                              42.7kB @ 123.7kB/s  0.0s
# hdf4                                               756.7kB @   2.1MB/s  0.1s
# waterdynamics                                       30.8kB @  83.2kB/s  0.0s
# mdanalysis                                           5.0MB @  13.5MB/s  0.1s
# [+] 0.4s
# Downloading  (4)  67%
# Extracting  (16)  ⣾  libgfortran-ng                                      54.1kB @ 133.2kB/s  0.0s
# netcdf4                                              1.1MB @   2.5MB/s  0.1s
# biopython                                            2.9MB @   5.9MB/s  0.1s
# [+] 0.5s
# Downloading  (1)  92%
# Extracting  (18)  ⣾  hdf5                                                 3.9MB @   7.2MB/s  0.2s
# [+] 0.6s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 0.7s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 0.8s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 0.9s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 1.0s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 1.1s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 1.2s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 1.3s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 1.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 1.6s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 1.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 1.8s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['mdtraj']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64                                            No change
# pkgs/r/noarch                                                 No change
# pkgs/r/linux-64                                               No change
# [+] 0.1s
# pkgs/main/noarch  ⣾  pkgs/main/noarch                                              No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - mdtraj
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package       Version  Build              Channel          Size
# ───────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────
#
#   + zlib-ng       2.2.3  h7955e40_0         conda-forge     109kB
#   + c-blosc2     2.15.2  h3122c55_1         conda-forge     342kB
#   + py-cpuinfo    9.0.0  pyhd8ed1ab_1       conda-forge      26kB
#   + nomkl           1.0  h5ca1d4c_0         conda-forge       4kB
#   + numexpr      2.10.2  py310hdb6e06b_100  conda-forge     173kB
#   + pytables     3.10.1  py310h1affd9f_4    conda-forge       1MB
#   + mdtraj       1.10.2  py310h4cdbd58_0    conda-forge       2MB
#
#   Summary:
#
#   Install: 7 packages
#
#   Total download: 4MB
#
# ───────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%py-cpuinfo                                          25.8kB @ 442.3kB/s  0.1s
# zlib-ng                                            108.7kB @   1.4MB/s  0.1s
# nomkl                                                3.8kB @  47.9kB/s  0.1s
# [+] 0.1s
# Downloading  (4)   4%
# Extracting   (3)  ⣾  c-blosc2                                           341.8kB @   3.2MB/s  0.1s
# numexpr                                            173.2kB @   1.6MB/s  0.1s
# pytables                                             1.5MB @  11.4MB/s  0.1s
# mdtraj                                               1.6MB @  10.0MB/s  0.1s
# [+] 0.2s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 0.3s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 0.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 0.5s
# Downloading      100%
# Extracting       100%
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['plip']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - plip
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package    Version  Build            Channel          Size
# ──────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────
#
#   + libxslt   1.1.39  h76b75d6_0       conda-forge     254kB
#   + lxml       5.3.0  py310h6ee67d5_2  conda-forge       1MB
#   + plip       2.3.1  pyh29332c3_1     conda-forge      77kB
#
#   Summary:
#
#   Install: 3 packages
#
#   Total download: 2MB
#
# ──────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading  (3)   0%
# Extracting         0%plip                                                76.5kB @ 959.1kB/s  0.1s
# [+] 0.1s
# Downloading  (2)   6%
# Extracting   (1)  ⣾  libxslt                                            254.3kB @   2.3MB/s  0.1s
# lxml                                                 1.4MB @  12.0MB/s  0.1s
# [+] 0.2s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 0.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 0.4s
# Downloading      100%
# Extracting       100%
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['openmm']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/noarch                                              No change
# pkgs/r/noarch                                                 No change
# pkgs/r/linux-64                                               No change
# pkgs/main/linux-64                                            No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - openmm
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                       Version  Build            Channel           Size
# ──────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────
#
#   + cudatoolkit                  11.8.0  h4ba93d1_13      conda-forge      716MB
#   + opencl-headers           2024.10.24  h5888daf_0       conda-forge       54kB
#   + ocl-icd                       2.3.2  hb9d3cd8_2       conda-forge       95kB
#   + ocl-icd-system                1.0.0  1                conda-forge        4kB
#   + kernel-headers_linux-64      3.10.0  he073ed8_18      conda-forge      943kB
#   + sysroot_linux-64               2.17  h0157908_18      conda-forge       15MB
#   + openmm                        8.2.0  py310h6b72300_0  conda-forge       12MB
#
#   Downgrade:
# ──────────────────────────────────────────────────────────────────────────────────
#
#   - numpy                         2.2.1  py310h5851e9f_0  conda-forge     Cached
#   + numpy                        1.26.4  py310hb13e2d6_0  conda-forge        7MB
#   - scipy                        1.15.1  py310hfa6ec8c_0  conda-forge     Cached
#   + scipy                        1.13.1  py310h93e2701_0  conda-forge       17MB
#
#   Summary:
#
#   Install: 7 packages
#   Downgrade: 2 packages
#
#   Total download: 767MB
#
# ──────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading  (1)   0%
# Extracting         0%ocl-icd                                             94.9kB @   1.5MB/s  0.1s
# opencl-headers                                      54.1kB @ 650.0kB/s  0.1s
# [+] 0.1s
# Downloading  (5)   1%
# Extracting   (2)  ⣾  ocl-icd-system                                       4.3kB @  37.3kB/s  0.0s
# kernel-headers_linux-64                            943.5kB @   8.0MB/s  0.1s
# [+] 0.2s
# Downloading  (5)   2%
# Extracting   (2)  ⣾  [+] 0.3s
# Downloading  (5)   4%
# Extracting   (1)  ⣾  openmm                                              11.7MB @  31.1MB/s  0.3s
# [+] 0.4s
# Downloading  (4)   8%
# Extracting   (2)  ⣾  scipy                                               16.5MB @  40.3MB/s  0.4s
# numpy                                                7.0MB @  14.9MB/s  0.5s
# sysroot_linux-64                                    15.2MB @  32.2MB/s  0.4s
# [+] 0.5s
# Downloading  (1)  10%
# Extracting   (4)  ⣾  [+] 0.6s
# Downloading  (1)  11%
# Extracting   (4)  ⣾  [+] 0.7s
# Downloading  (1)  12%
# Extracting   (4)  ⣾  [+] 0.8s
# Downloading  (1)  13%
# Extracting   (4)  ⣾  [+] 0.9s
# Downloading  (1)  15%
# Extracting   (4)  ⣾  [+] 1.0s
# Downloading  (1)  16%
# Extracting   (4)  ⣾  [+] 1.1s
# Downloading  (1)  17%
# Extracting   (4)  ⣾  [+] 1.2s
# Downloading  (1)  17%
# Extracting   (4)  ⣾  [+] 1.3s
# Downloading  (1)  19%
# Extracting   (4)  ⣾  [+] 1.4s
# Downloading  (1)  20%
# Extracting   (4)  ⣾  [+] 1.5s
# Downloading  (1)  21%
# Extracting   (4)  ⣾  [+] 1.6s
# Downloading  (1)  22%
# Extracting   (4)  ⣾  [+] 1.7s
# Downloading  (1)  22%
# Extracting   (3)  ⣾  [+] 1.8s
# Downloading  (1)  23%
# Extracting   (2)  ⣾  [+] 1.9s
# Downloading  (1)  24%
# Extracting   (2)  ⣾  [+] 2.0s
# Downloading  (1)  25%
# Extracting   (2)  ⣾  [+] 2.1s
# Downloading  (1)  26%
# Extracting   (2)  ⣾  [+] 2.2s
# Downloading  (1)  27%
# Extracting   (2)  ⣾  [+] 2.3s
# Downloading  (1)  27%
# Extracting   (2)  ⣾  [+] 2.4s
# Downloading  (1)  27%
# Extracting   (2)  ⣾  [+] 2.5s
# Downloading  (1)  28%
# Extracting   (2)  ⣾  [+] 2.6s
# Downloading  (1)  29%
# Extracting   (2)  ⣾  [+] 2.7s
# Downloading  (1)  29%
# Extracting   (2)  ⣾  [+] 2.8s
# Downloading  (1)  30%
# Extracting   (2)  ⣾  [+] 2.9s
# Downloading  (1)  31%
# Extracting   (2)  ⣾  [+] 3.0s
# Downloading  (1)  31%
# Extracting   (2)  ⣾  [+] 3.1s
# Downloading  (1)  32%
# Extracting   (2)  ⣾  [+] 3.2s
# Downloading  (1)  33%
# Extracting   (2)  ⣾  [+] 3.3s
# Downloading  (1)  34%
# Extracting        89%[+] 3.4s
# Downloading  (1)  36%
# Extracting        89%[+] 3.5s
# Downloading  (1)  38%
# Extracting        89%[+] 3.6s
# Downloading  (1)  39%
# Extracting        89%[+] 3.7s
# Downloading  (1)  41%
# Extracting        89%[+] 3.8s
# Downloading  (1)  42%
# Extracting        89%[+] 3.9s
# Downloading  (1)  44%
# Extracting        89%[+] 4.0s
# Downloading  (1)  46%
# Extracting        89%[+] 4.1s
# Downloading  (1)  47%
# Extracting        89%[+] 4.2s
# Downloading  (1)  48%
# Extracting        89%[+] 4.3s
# Downloading  (1)  49%
# Extracting        89%[+] 4.4s
# Downloading  (1)  50%
# Extracting        89%[+] 4.5s
# Downloading  (1)  51%
# Extracting        89%[+] 4.6s
# Downloading  (1)  52%
# Extracting        89%[+] 4.7s
# Downloading  (1)  53%
# Extracting        89%[+] 4.8s
# Downloading  (1)  55%
# Extracting        89%[+] 4.9s
# Downloading  (1)  56%
# Extracting        89%[+] 5.0s
# Downloading  (1)  56%
# Extracting        89%[+] 5.1s
# Downloading  (1)  57%
# Extracting        89%[+] 5.2s
# Downloading  (1)  58%
# Extracting        89%[+] 5.3s
# Downloading  (1)  59%
# Extracting        89%[+] 5.4s
# Downloading  (1)  60%
# Extracting        89%[+] 5.5s
# Downloading  (1)  61%
# Extracting        89%[+] 5.6s
# Downloading  (1)  61%
# Extracting        89%[+] 5.7s
# Downloading  (1)  62%
# Extracting        89%[+] 5.8s
# Downloading  (1)  64%
# Extracting        89%[+] 5.9s
# Downloading  (1)  65%
# Extracting        89%[+] 6.0s
# Downloading  (1)  66%
# Extracting        89%[+] 6.1s
# Downloading  (1)  67%
# Extracting        89%[+] 6.2s
# Downloading  (1)  68%
# Extracting        89%[+] 6.3s
# Downloading  (1)  69%
# Extracting        89%[+] 6.4s
# Downloading  (1)  71%
# Extracting        89%[+] 6.5s
# Downloading  (1)  72%
# Extracting        89%[+] 6.6s
# Downloading  (1)  73%
# Extracting        89%[+] 6.7s
# Downloading  (1)  74%
# Extracting        89%[+] 6.8s
# Downloading  (1)  75%
# Extracting        89%[+] 6.9s
# Downloading  (1)  76%
# Extracting        89%[+] 7.0s
# Downloading  (1)  77%
# Extracting        89%[+] 7.1s
# Downloading  (1)  78%
# Extracting        89%[+] 7.2s
# Downloading  (1)  78%
# Extracting        89%[+] 7.3s
# Downloading  (1)  79%
# Extracting        89%[+] 7.4s
# Downloading  (1)  81%
# Extracting        89%[+] 7.5s
# Downloading  (1)  81%
# Extracting        89%[+] 7.6s
# Downloading  (1)  82%
# Extracting        89%[+] 7.7s
# Downloading  (1)  83%
# Extracting        89%[+] 7.8s
# Downloading  (1)  84%
# Extracting        89%[+] 7.9s
# Downloading  (1)  85%
# Extracting        89%[+] 8.0s
# Downloading  (1)  85%
# Extracting        89%[+] 8.1s
# Downloading  (1)  86%
# Extracting        89%[+] 8.2s
# Downloading  (1)  86%
# Extracting        89%[+] 8.3s
# Downloading  (1)  87%
# Extracting        89%[+] 8.4s
# Downloading  (1)  89%
# Extracting        89%[+] 8.5s
# Downloading  (1)  90%
# Extracting        89%[+] 8.6s
# Downloading  (1)  91%
# Extracting        89%[+] 8.7s
# Downloading  (1)  93%
# Extracting        89%[+] 8.8s
# Downloading  (1)  95%
# Extracting        89%[+] 8.9s
# Downloading  (1)  96%
# Extracting        89%[+] 9.0s
# Downloading  (1)  97%
# Extracting        89%[+] 9.1s
# Downloading  (1)  99%
# Extracting        89%[+] 9.2s
# Downloading  (1)  99%
# Extracting        89%cudatoolkit                                        715.6MB @  77.3MB/s  9.3s
# [+] 9.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.9s
# Downloading      100%
# ...
#
# ──────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%sphinx-gallery                                     385.5kB @   4.9MB/s  0.1s
# [+] 0.1s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['autodocsumm']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64                                            No change
# pkgs/main/noarch                                              No change
# pkgs/r/noarch                                                 No change
# pkgs/r/linux-64                                               No change
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - autodocsumm
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package        Version  Build         Channel         Size
# ──────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────
#
#   + autodocsumm   0.2.14  pyhd8ed1ab_0  conda-forge     19kB
#
#   Summary:
#
#   Install: 1 packages
#
#   Total download: 19kB
#
# ──────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%autodocsumm                                         19.2kB @ 242.8kB/s  0.1s
# [+] 0.1s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done
# Collecting black-nb
#   Downloading black-nb-0.7.tar.gz (10 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting nbsphinx-link
#   Downloading nbsphinx_link-1.3.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting sphinxext-opengraph
#   Downloading sphinxext_opengraph-0.9.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting deepchem
#   Downloading deepchem-2.8.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.10/site-packages (from black-nb) (24.3.0)
# Collecting black>=21.9b0 (from black[jupyter]>=21.9b0->black-nb)
#   Downloading black-24.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 5.3 MB/s eta 0:00:00
# Collecting click>=7.0 (from black-nb)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: nbformat>=4.4.0 in /usr/local/lib/python3.10/site-packages (from black-nb) (5.10.4)
# Requirement already satisfied: nbsphinx in /usr/local/lib/python3.10/site-packages (from nbsphinx-link) (0.9.6)
# Requirement already satisfied: sphinx>=1.8 in /usr/local/lib/python3.10/site-packages (from nbsphinx-link) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/site-packages (from deepchem) (1.4.2)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/site-packages (from deepchem) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/site-packages (from deepchem) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/site-packages (from deepchem) (1.6.1)
# Collecting sympy (from deepchem)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.10/site-packages (from deepchem) (1.13.1)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.10/site-packages (from deepchem) (2024.9.4)
# Collecting mypy-extensions>=0.4.3 (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/site-packages (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb) (23.2)
# Collecting pathspec>=0.9.0 (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/site-packages (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb) (4.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/site-packages (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/site-packages (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb) (4.12.2)
# Requirement already satisfied: ipython>=7.8.0 in /usr/local/lib/python3.10/site-packages (from black[jupyter]>=21.9b0->black-nb) (8.31.0)
# Collecting tokenize-rt>=3.2.0 (from black[jupyter]>=21.9b0->black-nb)
#   Downloading tokenize_rt-6.1.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/site-packages (from nbformat>=4.4.0->black-nb) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/site-packages (from nbformat>=4.4.0->black-nb) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/site-packages (from nbformat>=4.4.0->black-nb) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.10/site-packages (from nbformat>=4.4.0->black-nb) (5.14.3)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (1.1.10)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (3.1.5)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.19.1)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.16.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.10/site-packages (from sphinx>=1.8->nbsphinx-link) (2.31.0)
# Requirement already satisfied: nbconvert!=5.4,>=5.3 in /usr/local/lib/python3.10/site-packages (from nbsphinx->nbsphinx-link) (7.16.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/site-packages (from pandas->deepchem) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas->deepchem) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/site-packages (from pandas->deepchem) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/site-packages (from scikit-learn->deepchem) (3.5.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->deepchem)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (5.1.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (3.0.48)
# Requirement already satisfied: stack_data in /usr/local/lib/python3.10/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/site-packages (from Jinja2>=3.1->sphinx>=1.8->nbsphinx-link) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.4.0->black-nb) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.4.0->black-nb) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.4.0->black-nb) (0.22.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (3.1.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (1.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->deepchem) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests>=2.30.0->sphinx>=1.8->nbsphinx-link) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests>=2.30.0->sphinx>=1.8->nbsphinx-link) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests>=2.30.0->sphinx>=1.8->nbsphinx-link) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests>=2.30.0->sphinx>=1.8->nbsphinx-link) (2024.12.14)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.8.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/site-packages (from nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (7.4.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (2.5)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/site-packages (from stack_data->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/site-packages (from stack_data->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (3.0.0)
# Requirement already satisfied: pure_eval in /usr/local/lib/python3.10/site-packages (from stack_data->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.2.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (1.6.0)
# Requirement already satisfied: pyzmq>=23.0 in /usr/local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (6.4.2)
# Downloading nbsphinx_link-1.3.1-py3-none-any.whl (5.2 kB)
# Downloading sphinxext_opengraph-0.9.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.6 MB/s eta 0:00:00
# Downloading deepchem-2.8.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.0 MB/s eta 0:00:00
# Downloading black-24.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 56.1 MB/s eta 0:00:00
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 8.5 MB/s eta 0:00:00
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 82.9 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 34.5 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading tokenize_rt-6.1.0-py2.py3-none-any.whl (6.0 kB)
# Building wheels for collected packages: black-nb
#   Building wheel for black-nb (pyproject.toml) ... done
#   Created wheel for black-nb: filename=black_nb-0.7-py3-none-any.whl size=10124 sha256=2100de6a5d19b733c0307bfe7942d2f3391996219ee8b309e2240d5b12747d70
#   Stored in directory: /root/.cache/pip/wheels/76/ff/85/64463651f1a17014becf8551aea16305e094025de91e7e3911
# Successfully built black-nb
# Installing collected packages: mpmath, tokenize-rt, sympy, pathspec, mypy-extensions, click, black, sphinxext-opengraph, deepchem, black-nb, nbsphinx-link
# Successfully installed black-24.10.0 black-nb-0.7 click-8.1.8 deepchem-2.8.0 mpmath-1.3.0 mypy-extensions-1.0.0 nbsphinx-link-1.3.1 pathspec-0.12.1 sphinxext-opengraph-0.9.1 sympy-1.13.3 tokenize-rt-6.1.0

# %% [markdown]
# ## Practical

# %%
import time
import random
from pathlib import Path

import pandas as pd
import numpy
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit import DataStructs
from rdkit.ML.Cluster import Butina
from rdkit.Chem import Draw
from rdkit.Chem import rdFingerprintGenerator

# %% [markdown]
# ### Load and draw molecules
#
# Cluster data taken from **Part 5** or later HSP70 molecules from **Part 1**

# %%
sdf = str("/content/molecule_set_largest_cluster.sdf")
supplier = Chem.ForwardSDMolSupplier(sdf)
mols = list(supplier)

print(f"Set with {len(mols)} molecules loaded.")
# NBVAL_CHECK_OUTPUT
# Out:
# Set with 20 molecules loaded.

# %%
# Show only first 10 molecules -- use slicing
num_mols = 10
legends = [mol.GetProp("_Name") for mol in mols]
Draw.MolsToGridImage(mols[:num_mols], legends=legends[:num_mols], molsPerRow=5)

# %% [markdown]
# ### Run the FMCS algorithm with different input parameters
#
# The FMCS algorithm is implemented in RDKit: [rdFMCS](https://rdkit.org/docs/source/rdkit.Chem.rdFMCS.html)

# %% [markdown]
# #### Default values
#
# In the simplest case only a list of molecules is given as a parameter.

# %%
from rdkit import Chem
from rdkit.Chem import rdFMCS # Import rdFMCS explicitly
from rdkit import DataStructs
from rdkit.ML.Cluster import Butina
from rdkit.Chem import Draw
from rdkit.Chem import rdFingerprintGenerator

mcs1 = rdFMCS.FindMCS(mols)
print(f"MCS1 contains {mcs1.numAtoms} atoms and {mcs1.numBonds} bonds.")
print("MCS SMARTS string:", mcs1.smartsString)
# NBVAL_CHECK_OUTPUT
# Out:
# MCS1 contains 16 atoms and 18 bonds.
# MCS SMARTS string: [#8]=[#6](-[#8])-[#6]1-[#7]-[#6]2:[#6]:[#6]:[#6]:[#6]:[#6]:2-[#6]2-[#6]-1-[#6]-[#6]=[#6]-2

# %%
# Draw substructure from Smarts
m1 = Chem.MolFromSmarts(mcs1.smartsString)
Draw.MolToImage(m1, legend="MCS1")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# Define a helper function to draw the molecules with the highlighted MCS.

# %%
from rdkit import Chem
from rdkit.Chem import rdFMCS # Import rdFMCS explicitly
from rdkit import DataStructs
from rdkit.ML.Cluster import Butina
from rdkit.Chem import Draw, AllChem
from rdkit.Chem import rdFingerprintGenerator
from rdkit.Geometry import Point2D, Point3D # Import Point2D
import copy
from copy import deepcopy

def highlight_molecules(molecules, mcs, number, label=True, same_orientation=True, **kwargs):
    """Highlight the MCS in the query molecules"""
    # The error was caused because the deepcopy function was not imported. Adding this line fixes it.
    molecules = deepcopy(molecules)
    # convert MCS to molecule
    pattern = Chem.MolFromSmarts(mcs.smartsString)
    # find the matching atoms in each molecule
    matching = [molecule.GetSubstructMatch(pattern) for molecule in molecules[:number]]

    legends = None
    if label is True:
        legends = [x.GetProp("_Name") for x in molecules]

    # Align by matched substructure so they are depicted in the same orientation
    # Adapted from: https://gist.github.com/greglandrum/82d9a86acb3b00d3bb1df502779a5810
    if same_orientation:
        mol, match = molecules[0], matching[0]
        AllChem.Compute2DCoords(mol)
        coords = [mol.GetConformer().GetAtomPosition(x) for x in match]
        # Use Point2D instead of Point3D
        coords2D = [Point2D(pt.x, pt.y) for pt in coords]
        for mol, match in zip(molecules[1:number], matching[1:number]):
            if not match:
                continue
            coord_dict = {match[i]: coord for i, coord in enumerate(coords2D)}
            AllChem.Compute2DCoords(mol, coordMap=coord_dict)

    return Draw.MolsToGridImage(
        molecules[:number],
        legends=legends,
        molsPerRow=5,
        highlightAtomLists=matching[:number],
        subImgSize=(200, 200),
        **kwargs,
    )

# %%
highlight_molecules(mols, mcs1, 5)

# %% [markdown]
# Save image to disk

# %%
img = highlight_molecules(mols, mcs1, 3, useSVG=True)

# Get SVG data
molsvg = img.data

# Set background to transparent & Enlarge size of label
molsvg = molsvg.replace("opacity:1.0", "opacity:0.0").replace("12px", "20px")

# Save altered SVG data to file
with open("mcs_largest_cluster.svg", "w") as f:
    f.write(molsvg)

# %% [markdown]
# #### Set a threshold
#
# It is possible to lower the threshold for the substructure, for example so that the MCS only has to occur in e.g. 80% of the input structures.

# %%
mcs2 = rdFMCS.FindMCS(mols, threshold=0.8)
print(f"MCS2 contains {mcs2.numAtoms} atoms and {mcs2.numBonds} bonds.")
print("SMARTS string:", mcs2.smartsString)
# NBVAL_CHECK_OUTPUT
# Out:
# MCS2 contains 16 atoms and 18 bonds.
# SMARTS string: [#8]=[#6](-[#8])-[#6]1-[#7]-[#6]2:[#6]:[#6]:[#6]:[#6]:[#6]:2-[#6]2-[#6]-1-[#6]-[#6]=[#6]-2

# %%
# Draw substructure
m2 = Chem.MolFromSmarts(mcs2.smartsString)
Draw.MolsToGridImage([m1, m2], legends=["MCS1", "MCS2: +threshold=0.8"])

# %%
highlight_molecules(mols, mcs2, 5)

# %% [markdown]
# <!-- FIXME: CI - CHEMBL27685 id is not in this subset, check that T005 produces deterministic outputs -->
# As seen in this example, some molecules were now left out due to the set threshold (`0.8`). This threshold allows to find a larger common substructure that contains, e.g., a benzene with a meta-substitution fluor pattern and a longer alkane chain.

# %% [markdown]
# #### Match ring bonds
#
# In the above example it may not be obvious, but by default ring bonds can match non-ring bonds.
# Often from an application point of view, one may want to retain rings. Thus, one can set the `ringMatchesRingOnly` parameter to ```True```, then only ring bonds match with other ring bonds.

# %%
mcs3 = rdFMCS.FindMCS(mols, threshold=0.8, ringMatchesRingOnly=True)
print(f"MCS3 contains {mcs3.numAtoms} atoms and {mcs3.numBonds} bonds.")
print("SMARTS string:", mcs3.smartsString)
# NBVAL_CHECK_OUTPUT
# Out:
# MCS3 contains 16 atoms and 18 bonds.
# SMARTS string: [#8&!R]=&!@[#6&!R](-&!@[#8&!R])-&!@[#6]1-&@[#7]-&@[#6]2:&@[#6]:&@[#6]:&@[#6]:&@[#6]:&@[#6]:&@2-&@[#6]2-&@[#6]-&@1-&@[#6]-&@[#6]=&@[#6]-&@2

# %%
# Draw substructure
m3 = Chem.MolFromSmarts(mcs3.smartsString)
Draw.MolsToGridImage([m1, m2, m3], legends=["MCS1", "MCS2: +treshold=0.8", "mcs3: +ringmatch"])

# %% [markdown]
# Depending on the chosen thresholds and parameters, I got slightly different MCS. More parameter options are available in the [RDKit FMCS module](https://www.rdkit.org/docs/GettingStartedInPython.html#maximum-common-substructure), e.g. considering atom, bond or valence matching.

# %%
highlight_molecules(mols, mcs3, 5)

# %% [markdown]
# ### A more diverse set: the HSP70 compounds downloaded from ChEMBL
#
# I restricted the data to only highly active molecules (pIC50>9) and detect the maximum common scaffold in this subset.

# %%
# Read full HSP70 data
mol_df = pd.read_csv("/content/ro5_properties.csv", index_col=0)
print("Total number of compounds:", mol_df.shape[0])

# Only keep molecules with pIC50 > 9 (IC50 > 1nM)
mol_df = mol_df[mol_df.pIC50 > 9]
print("Number of compounds with pIC50 > 9:", mol_df.shape[0])
# NBVAL_CHECK_OUTPUT

# Check if the filtered DataFrame is empty
if mol_df.empty:
    print("Warning: No compounds with pIC50 > 9 found. Using all compounds instead.")
    mol_df = pd.read_csv("/content/ro5_properties.csv", index_col=0)  # Reload the original DataFrame


from rdkit.Chem import PandasTools # Add this line to import PandasTools

# Add molecule column to data frame
PandasTools.AddMoleculeColumnToFrame(mol_df, "smiles")
mol_df.head(3)
# Out:
# Total number of compounds: 43
# Number of compounds with pIC50 > 9: 0
# Warning: No compounds with pIC50 > 9 found. Using all compounds instead.
#   molecule_chembl_id  IC50 units  \
# 0       CHEMBL502775   332    nM
# 1      CHEMBL1481974   578    nM
# 2       CHEMBL471004   634    nM
#
#                                               smiles     pIC50  \
# 0      O=C(O)/C=C/c1c2ccc(=O)c(O)c-2oc2c(O)c(O)ccc12  6.478862
# 1         O=C(O)CCc1c2ccc(=O)c(O)c-2oc2c(O)c(O)ccc12  6.238072
# 2  CC1C2C=CC1C(c1c3ccc(=O)c(O)c-3oc3c(O)c(O)ccc13...  6.197911
#
#    molecular_weight  n_hba  n_hbd    logp  ro5_fulfilled  \
# 0        314.042653      6      4  2.1124           True
# 1        316.058303      6      4  2.0318           True
# 2        394.105253      6      4  3.2509           True
#
#                                               ROMol
# 0  <rdkit.Chem.rdchem.Mol object at 0x7c89b9e7c0b0>
# 1  <rdkit.Chem.rdchem.Mol object at 0x7c89b9e7c120>
# 2  <rdkit.Chem.rdchem.Mol object at 0x7c89b9e7c190>

# %% [markdown]
# I did my calculations on the selected highly active molecules only.

# %%
mols_diverse = []
# Discarded variables I did not care about are usually referred to with a single underscore
for _, row in mol_df.iterrows():
    m = Chem.MolFromSmiles(row.smiles)
    m.SetProp("_Name", row.molecule_chembl_id)
    mols_diverse.append(m)

# %% [markdown]
# In the interest of time, I randomly picked 50 molecules from this set.

# %%
# I fixed the random seed above (imports) for deterministic results
# Get the minimum between the desired sample size and the population size
sample_size = min(len(mols_diverse), 50)
mols_diverse_sample = random.sample(mols_diverse, sample_size)

# %% [markdown]
# I now calculated the same three variants of MCSs as described above and draw the respective substructures. I used a slightly lower threshold to account for the larger diversity in the set.

# %%
threshold_diverse = 0.7
mcs1 = rdFMCS.FindMCS(mols_diverse_sample)
print("SMARTS string1:", mcs1.smartsString)
mcs2 = rdFMCS.FindMCS(mols_diverse_sample, threshold=threshold_diverse)
print("SMARTS string2:", mcs2.smartsString)
mcs3 = rdFMCS.FindMCS(mols_diverse_sample, ringMatchesRingOnly=True, threshold=threshold_diverse)
print("SMARTS string3:", mcs3.smartsString)
# NBVAL_CHECK_OUTPUT
# Out:
# SMARTS string1: [#6]-,:[#6]:,-[#6]:,-[#6]:,-[#6]
# SMARTS string2: [#6](-[#8])-,:[#6]-,:[#6](-,:[#6])-,:[#6](-,:[#6]:,-[#6]:,-[#6]:,-[#6]:,-[#6]:,-[#6])-,:[#6]
# SMARTS string3: [#6]1:&@[#6]:&@[#6]:&@[#6]:&@[#6]:,-;@[#6]:&@1-,:;@[#6&R]-,:;@[#6&R](-,:;@[#6&R]-,:;@[#6&R])-,:;@[#6&R]

# %%
# Draw substructures
m1 = Chem.MolFromSmarts(mcs1.smartsString)
m2 = Chem.MolFromSmarts(mcs2.smartsString)
m3 = Chem.MolFromSmarts(mcs3.smartsString)

Draw.MolsToGridImage(
    [m1, m2, m3],
    legends=[
        "MCS1",
        f"MCS2: +threshold={threshold_diverse}",
        "MCS3: +ringmatch",
    ],
)

# %% [markdown]
# This time it become more clear that setting `ringMatchesRingOnly=True` provides a more intuitive representation of the scaffold they share.

# %%
highlight_molecules(mols_diverse_sample, mcs3, 5)

# %% [markdown]
# ### Identification of MCS using interactive cut-off adaption
#
# I can also change the threshold interactively. For that, I needed a helper function, hereby defined. It takes two arguments: `molecules` (fixed, so it's not configurable with a widget) and `percentage` (the value of which is determined by the interactive widget). Every time you modify the state of the slider, this helper function is called.

# %%
from ipywidgets import interact, fixed, widgets # Import the interact and fixed functions

def render_mcs(molecules, percentage):
    """Interactive widget helper. `molecules` must be wrapped in `ipywidgets.fixed()`,
    while `percentage` will be determined by an IntSlider widget."""
    tmcs = rdFMCS.FindMCS(molecules, threshold=percentage / 100.0)
    if tmcs is None:
        print("No MCS found")
        return None

    m = Chem.MolFromSmarts(tmcs.smartsString)
    print(tmcs.smartsString)
    return m

# %%
# Note that the slider may take a few seconds to react
interact(
    render_mcs,
    molecules=fixed(mols_diverse_sample),
    percentage=widgets.IntSlider(min=0, max=100, step=10, value=70),
);
# Out:
# interactive(children=(IntSlider(value=70, description='percentage', step=10), Output()), _dom_classes=('widget…
